# %% [markdown]
# <center><p float="center">
#   <img src="https://upload.wikimedia.org/wikipedia/commons/e/e9/4_RGB_McCombs_School_Brand_Branded.png" width="300" height="100"/>
#   <img src="https://mma.prnewswire.com/media/1458111/Great_Learning_Logo.jpg?p=facebook" width="200" height="100"/>
# </p></center>
#
# <h1><center><font size=10>Artificial Intelligence and Machine Learning</center></font></h1>
# <h1><center>Introduction to Natural Language Processing - Week 3</center></h1>

# %% [markdown]
# <center><img src="https://cdn.pixabay.com/photo/2018/03/06/08/31/drone-3202860_1280.jpg" width="720"/></center>
#
# <center><font size=5>Product Reviews Sentiment Analysis </center></font>

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Business Context

# %% [markdown]
# In the rapidly evolving landscape of e-commerce, customer reviews play a pivotal role in shaping the perception of products and influencing purchasing decisions. All businesses recognize the significance of understanding customer sentiment and extracting valuable insights from the vast pool of customer reviews to drive decisions. The inability to actively track customer feedback can result in significant challenges for businesses. Negative sentiments expressed by customers become crucial to track and resolve as they can lead to several detrimental effects, including:
#
# 1. Customer Churn: Unaddressed negative sentiment can lead to customer dissatisfaction and the potential loss of loyal customers. This may result in customers opting for alternative platforms for their future purchases, impacting long-term revenue and market share.
#
# 2. Reputation Damage: The persistence of negative sentiment, if not effectively managed, can tarnish the reputation of the business. Potential customers may be dissuaded from making purchases on the platform due to concerns raised in negative reviews, affecting brand loyalty and trust.
#
# 3. Financial Implications: Negative sentiment can lead to a decline in sales, impacting profitability. Discouraged by negative feedback, potential customers may choose competitors, resulting in direct financial repercussions for the company.

# %% [markdown]
# ### Problem Definition

# %% [markdown]
# A rising e-commerce platform in the space of electronic gadgets captures customer feedback through different channels, such as product review forms, surveys, and more. In addition, they also capture customer feedback from social media platforms. After witnessing a 200% growth in their customer base in the last three years, they are now experiencing a substantial upswing in the number of customer feedbacks received, with a noteworthy increase of ~25% over the past six months.
#
# As they were previously monitoring customer feedback manually, this surge in customer feedback presents a multifaceted challenge for the business as the volume of reviews has surpassed the manual capacity to track and analyze effectively. Recognizing the need for a proactive and scalable solution, the organization seeks to employ artificial intelligence (AI) to aid them. The primary objective is to develop an AI solution that can automatically assess and categorize customer sentiments as negative, positive, or neutral by parsing and analyzing product reviews. As a Data Scientist, you are provided with the reviews shared by customers regarding their experience with the product along with the manually labeled sentiments of the reviews and asked to analyze the data and build a predictive model that can parse the customer reviews and predict the sentiment of the customer.

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# - **Product ID**: An exclusive identification number for each product
#
# - **Product Review**: Insights and opinions shared by customers about the product
#
# - **Sentiment**: Sentiment associated with the product review, indicating whether the review expresses a positive, negative, or neutral sentiment

# %% [markdown]
# ## Importing the necessary libraries

# %%
# installing the libraries for transformers
# !pip install -U -q sentence-transformers transformers bitsandbytes accelerate sentencepiece
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.7/345.7 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.7/354.7 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 56.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 50.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.1 MB/s eta 0:00:00

# %%
# to read and manipulate the data
import pandas as pd
import numpy as np
pd.set_option('max_colwidth', None)    # setting column to the maximum column width as per the data

# to visualise data
import matplotlib.pyplot as plt
import seaborn as sns

# Deep Learning library
import torch

# to load transformer models
from sentence_transformers import SentenceTransformer
from transformers import T5Tokenizer, T5ForConditionalGeneration, pipeline

# to split the data
from sklearn.model_selection import train_test_split

# to compute performance metrics
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# To build a Random Forest model
from sklearn.ensemble import RandomForestClassifier


# to ignore unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# loading data into a pandas dataframe
reviews = pd.read_csv("/content/drive/MyDrive/Python Course_shared/NLP/Product_Reviews.csv")

# %%
# creating a copy of the data
data = reviews.copy()

# %% [markdown]
# ## Data Overview

# %% [markdown]
# ### Checking the first five rows of the data

# %%
data.head(5)
# Out:
#              Product ID  \
# 0  AVpe7AsMilAPnD_xQ78G
# 1  AVpe7AsMilAPnD_xQ78G
# 2  AVpe7AsMilAPnD_xQ78G
# 3  AVpe7AsMilAPnD_xQ78G
# 4  AVpe7AsMilAPnD_xQ78G
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Product Review  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      I initially had trouble deciding between the paperwhite and the voyage because reviews more or less said the same thing: the paperwhite is great, but if you have spending money, go for the voyage.Fortunately, I had friends who owned each, so I ended up buying the paperwhite on this basis: both models now have 300 ppi, so the 80 dollar jump turns out pricey the voyage's page press isn't always sensitive, and if you are fine with a specific setting, you don't need auto light adjustment).It's been a week and I am loving my paperwhite, no regrets! The touch screen is receptive and easy to use, and I keep the light at a specific setting regardless of the time of day. (In any case, it's not hard to change the setting either, as you'll only be changing the light level at a certain time of day, not every now and then while reading).Also glad that I went for the international shipping option with Amazon. Extra expense, but delivery was on time, with tracking, and I didnt need to worry about customs, which I may have if I used a third party shipping service.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Allow me to preface this with a little history. I am (was) a casual reader who owned a Nook Simple Touch from 2011. I've read the Harry Potter series, Girl with the Dragon Tattoo series, 1984, Brave New World, and a few other key titles. Fair to say my Nook did not get as much use as many others may have gotten from theirs.Fast forward to today. I have had a full week with my new Kindle Paperwhite and I have to admit, I'm in love. Not just with the Kindle, but with reading all over again! Now let me relate this review, love, and reading all back to the Kindle. The investment of 139.00 is in the experience you will receive when you buy a Kindle. You are not simply paying for a screen there is an entire experience included in buying from Amazon.I have been reading The Hunger Games trilogy and shall be moving onto the Divergent series soon after. Here is the thing with the Nook that hindered me for the past 4 years: I was never inspired to pick it up, get it into my hands, and just dive in. There was never that feeling of oh man, reading on this thing is so awesome. However, with my Paperwhite, I now have that feeling! That desire is back and I simply adore my Kindle. If you are considering purchasing one, stop thinking about it simply go for it. After a full week, 3 downloaded books, and a ton of reading, I still have half of my battery left as well.Make yourself happy. Inspire the reader inside of you.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        I am enjoying it so far. Great for reading. Had the original Fire since 2012. The Fire used to make my eyes hurt if I read too long. Haven't experienced that with the Paperwhite yet.
# 3                                                                                                                                                                                                                                                       I bought one of the first Paperwhites and have been very pleased with it its been a constant companion and I suppose Ive read, on average, a book every three days for the past however many years on it. I wouldnt give it up youd have to pry it from my cold dead fingers.For sundry logistical reasons, Ive also made good use of Amazons Kindle app on my iPhone. No Paperwhite screen, naturally, and all the cool usability that delivers, but it works well and has its own attractions as a companion to the Kindle.Of course, there are aspects of the Paperwhite which I would like to critique. Ah you knew that was coming somewhere, didnt you.As a member of BookBub, I get a daily list of alerts and book deals in my chosen genres. I take on many of them, however, Ive found that, even with the best will in the world, I cant keep up. Some days it seems that for every book I read, Ive bought two. Theres just so much good stuff out there! The accumulative effect of this is that the number of books actually on my Paperwhite has been creeping ever upward for some time. Its now at about 400.With this in mind, Ive noticed that while page-turning has remained exactly the same, just about every other action on the Kindle has become positively glacial. Not just very slow, but so slow you think its malfunctioning. The general consensus appears to be that its to be expected once one has that many books downloaded onto a Kindle, it will begin to behave in a flakey manner. This drives me mad. Amazon states it can hold thousands of books. I believe them. But I figure I would need a second Paperwhite to read while Im waiting for actions to complete on the first one.Read more
# 4  I have to say upfront - I don't like coroporate, hermetically closed stuff like anything by Apple or in this case, Amazon. I like having devices on which I can put anything I want and use it. But...I was a fairly happy user of a Nook Touch for several years, but couldn't use all its functionalities since I live in Serbia. Then I lost the Nook and since no other devices can actually be fully used in Serbia (buying books with them, using their online capabilities) except the Kindle, and since no one except Amazon ships to Serbia, and since I've actually been a happy Amazon customer since 2005 over friends' accounts and since 2007 through my own, and since the Kindle definitely has the best technology - why not buy itSo I did. What I read in many reviews about the screen/light of the Paperwhite and similar devices was no problem with mine. The light disperses just fine, except a few black blotches (maybe you can see it in the picture) at the bottom of the screen, which are actually shadows of the black plastic casing and thus can't really be avoided. As you can see in the picture without the light - there are no blotches with light out.The Paperwhite's screen is just marvelous at 300 ppi, the touchscreen works just fine, the store works here in Serbia, and in these two days I've been using it, I'm a happy guy.I had to get the hang on how to make sideloaded books behave at least almost like Amazon books, but that's fine. That's the one thing I'd like to see Amazon do in some future upgrades: make the Kindle treat sideloaded books just like the ones bought from them directly, with sharing funcion (quotes and Goodreads) enabled and so on.The size is perfect, it sits very well in the hand, the light doesn't hurt the eyes in the dark (like the light on a tab does)... the packaging was fine, no problems there and what remains to be seen now is the battery life.So far, I can only recommend it.
#
#   Sentiment
# 0  POSITIVE
# 1  POSITIVE
# 2  POSITIVE
# 3  POSITIVE
# 4  POSITIVE

# %% [markdown]
# ### Checking the shape of the dataset

# %%
data.shape
# Out:
# (1007, 3)

# %% [markdown]
# * The dataset has 1006 rows and 3 columns.

# %% [markdown]
# ### Checking for Missing Values

# %%
data.isnull().sum()
# Out:
# Product ID        0
# Product Review    0
# Sentiment         0
# dtype: int64

# %% [markdown]
# * There are no missing values in the data

# %% [markdown]
# ### Checking for duplicate values

# %%
# checking for duplicate values
data.duplicated().sum()
# Out:
# np.int64(2)

# %% [markdown]
# * There are 2 duplicate values in the dataset.
# * We'll drop them.

# %%
# dropping duplicate values
data = data.drop_duplicates()

data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
 # function to create labeled barplots

def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %% [markdown]
# ### Distribution of sentiments

# %%
labeled_barplot(data, "Sentiment", perc=True)

# %% [markdown]
# - Majority of the reviews are positive (\~85%), followed by neutral reviews (8%), and then the positive reviews (\~7%)

# %% [markdown]
# ## Defining the Model

# %%
# defining the model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# setting the device to GPU if available, else CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
data = data.reset_index(drop=True) # needed as index was not continious after drop duolicate

# %%
# encoding the dataset
embedding_matrix = model.encode(data['Product Review'], device=device, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]

# %%
# printing the shape of the embedding matrix
embedding_matrix.shape
# Out:
# (1005, 384)

# %%
# printing the embedding vector of the first review in the dataset
embedding_matrix[0,:]
# Out:
# array([-6.76346645e-02, -2.20813751e-02,  5.92418462e-02,  7.95964152e-02,
#         1.31206180e-03, -3.00335456e-02, -4.03319672e-02,  4.49672379e-02,
#        -7.75716603e-02,  3.47503275e-02,  4.47142199e-02, -1.00544393e-02,
#        -3.18467617e-02,  6.61096200e-02,  1.99794434e-02,  8.67501926e-03,
#         4.62193117e-02, -1.06432639e-01, -7.67746046e-02,  8.88167545e-02,
#         2.89340075e-02, -6.90293908e-02,  1.93163492e-02, -1.67264063e-02,
#        -3.00858356e-02, -4.06532316e-03, -6.03297763e-02, -4.48418744e-02,
#        -1.11918738e-02, -4.35903631e-02,  8.26881174e-03,  1.19992994e-01,
#        -6.16409294e-02, -9.02885862e-04,  5.56041952e-03, -5.00543453e-02,
#         8.40801075e-02, -1.02412470e-01,  6.85357396e-03, -1.57752176e-04,
#         6.99326815e-03, -7.78148100e-02, -1.14781028e-02,  7.40694478e-02,
#         1.58786625e-02, -5.03668115e-02,  4.27684560e-02,  9.10115018e-02,
#        -3.01588215e-02,  3.78680639e-02,  4.32796776e-02, -6.61094636e-02,
#         3.48587781e-02, -9.42781568e-02,  3.17410044e-02,  6.70365989e-02,
#         4.59920280e-02, -2.93704253e-02,  8.10119510e-02, -9.86418128e-02,
#        -8.43294486e-02,  3.70383672e-02, -5.10242432e-02, -2.77930610e-02,
#         9.42463614e-03,  1.25589892e-02, -6.88827708e-02, -3.28764766e-02,
#         1.75607037e-02, -2.52228100e-02, -3.91786247e-02,  4.93138060e-02,
#         9.48379114e-02,  4.17672331e-03,  2.45964341e-02, -7.80683234e-02,
#         5.59145361e-02, -4.04693857e-02, -7.25661516e-02, -6.61304034e-03,
#         9.67282131e-02, -1.20513132e-02, -5.66822849e-02,  9.20966491e-02,
#         3.94486301e-02, -1.32833183e-01,  4.30279262e-02,  7.67267272e-02,
#         5.75698726e-02, -8.65206681e-03,  2.92764511e-02, -3.18573527e-02,
#        -3.78751121e-02, -2.29878221e-02, -6.60211816e-02,  2.30658408e-02,
#        -2.56948322e-02, -1.68732218e-02, -1.33758616e-02, -3.65733355e-02,
#         4.51774001e-02,  1.69819240e-02,  2.20477823e-02, -2.53376402e-02,
#        -3.27893123e-02, -1.03090324e-01, -1.35867791e-02,  3.97473983e-02,
#        -5.80035448e-02, -1.89347025e-02,  4.08620164e-02, -5.31920278e-03,
#        -4.90348935e-02, -4.08514403e-03, -5.24758771e-02,  2.34310031e-02,
#         7.95549899e-03,  1.09926173e-02,  9.93682221e-02, -7.02436492e-02,
#         6.50906004e-03,  2.57259458e-02,  5.20440713e-02, -1.87442508e-02,
#        -6.38855174e-02,  1.12016695e-02,  1.04238629e-01,  1.20417761e-33,
#         7.60678807e-03,  6.21988252e-02, -1.11550987e-01, -8.47005323e-02,
#         6.25198707e-02, -5.20940125e-03, -6.42658323e-02, -1.11011313e-02,
#        -4.04898040e-02, -3.71026024e-02, -6.35776222e-02,  4.24750261e-02,
#        -2.80059949e-02,  6.31971583e-02,  6.30243048e-02, -1.42653827e-02,
#        -1.08332364e-02,  2.82162540e-02,  1.17582921e-02,  1.03744417e-01,
#         3.96951102e-02, -7.75385499e-02,  2.01972239e-02, -3.44156288e-03,
#         6.36086836e-02,  3.52720432e-02,  2.25458369e-02,  2.12020129e-02,
#         6.60269987e-03,  6.21845387e-03, -5.85632361e-02,  1.37561299e-02,
#         3.51381078e-02, -2.82331686e-02, -4.72184084e-02,  1.21808390e-03,
#        -3.95175554e-02, -1.12970434e-01, -4.79625426e-02, -2.31895056e-02,
#        -8.34974945e-02,  8.73256624e-02,  7.08147418e-03,  3.74312848e-02,
#         2.95377001e-02,  7.23158717e-02, -1.79571174e-02,  1.47106289e-03,
#         3.73607613e-02,  1.08813792e-01, -8.33591744e-02, -5.81191815e-02,
#        -3.27764153e-02, -2.70728897e-02, -2.79573221e-02, -2.00731587e-02,
#         6.95730075e-02, -2.36700103e-02,  9.50226113e-02, -8.96029640e-03,
#         5.44306263e-02,  1.79110584e-03,  2.77347937e-02, -3.30223851e-02,
#         2.85588820e-02,  8.53919983e-02, -2.61637457e-02,  1.46853067e-02,
#        -1.46769747e-01, -5.67088574e-02, -5.39782038e-03, -2.28614137e-02,
#         6.31079227e-02, -2.20756009e-02,  1.30383492e-01,  2.71280892e-02,
#         3.50637399e-02,  4.57932707e-03, -4.13727434e-03, -1.23617407e-02,
#        -4.81839664e-02,  9.10539776e-02, -5.44405635e-03, -9.31518711e-03,
#        -6.06325734e-03, -1.38264420e-02,  8.02728068e-03,  8.14043730e-02,
#        -8.58523473e-02,  1.20629109e-02,  3.29740569e-02,  2.46055815e-02,
#         7.89331794e-02, -1.20122563e-02, -3.25022675e-02, -7.13324043e-34,
#         1.01304231e-02, -1.19126393e-02,  1.13189798e-02,  6.40927851e-02,
#         1.60333570e-02,  7.00749503e-03, -9.70822573e-03,  5.92119582e-02,
#         6.90550506e-02,  1.03968792e-02, -2.45734211e-02,  1.97343458e-03,
#        -3.38441059e-02,  3.33317965e-02, -4.93010283e-02, -4.38065547e-03,
#         3.18389968e-03,  1.65327918e-02,  2.99786739e-02, -1.88862663e-02,
#         5.77242970e-02,  3.73553075e-02, -1.83650758e-02,  2.40996201e-02,
#         2.40405947e-02, -1.26134818e-02,  2.04891432e-02,  1.91134810e-02,
#        -6.22684695e-02, -1.54622626e-02, -8.72103795e-02,  6.11424968e-02,
#         4.83133607e-02,  6.01549335e-02, -4.44915704e-02,  9.43900496e-02,
#         5.36482669e-02,  8.26253816e-02,  3.09133772e-02,  1.06118500e-01,
#        -6.19014204e-02,  4.36877981e-02,  9.02354810e-03, -1.33656040e-02,
#        -5.97936437e-02,  7.99864456e-02, -7.64158890e-02,  7.12151080e-03,
#        -2.32158583e-02,  1.75505001e-02, -7.60725141e-02,  1.66937914e-02,
#         4.20421697e-02, -4.22610566e-02, -4.69769761e-02,  2.16981978e-03,
#        -8.50258023e-03, -4.11793031e-02, -7.75425583e-02,  2.26793140e-02,
#        -4.44955304e-02,  1.02366833e-02, -9.87195503e-03,  7.00621307e-02,
#        -6.16097338e-02, -1.00842742e-02,  7.23319203e-02,  2.48797494e-03,
#         1.64485313e-02,  2.69716289e-02, -1.12344414e-01, -4.36550155e-02,
#         1.61729008e-02,  2.16798927e-03,  8.30070078e-02, -1.94688570e-02,
#        -4.91923327e-03,  1.32435258e-03,  5.24918269e-03, -1.13523398e-02,
#        -3.13487253e-03,  4.45024110e-03,  8.67053494e-03, -7.66487094e-03,
#        -1.58788301e-02,  4.37922142e-02, -6.55877814e-02, -7.21123144e-02,
#        -3.60154081e-03,  1.01997685e-02, -6.08589966e-03,  3.42696682e-02,
#         1.18951220e-02, -3.03071514e-02,  2.50035692e-02, -5.08846618e-08,
#        -2.84896996e-02, -1.14459293e-02,  7.34164491e-02, -6.00465981e-04,
#        -6.10274170e-03, -6.99888691e-02,  7.62297288e-02,  6.90106228e-02,
#        -9.76175349e-03,  2.44860705e-02,  3.01007982e-02, -8.50628838e-02,
#        -1.30330678e-02,  2.83161290e-02, -3.39693800e-02,  2.60680206e-02,
#         8.55710655e-02, -1.83585901e-02, -3.06644067e-02,  2.50635967e-02,
#         4.27763574e-02, -4.16117115e-03,  9.06008184e-02, -1.15957549e-02,
#         4.69538160e-02,  6.86350539e-02, -1.88715048e-02,  2.54306644e-02,
#        -3.44901159e-02, -7.51005188e-02,  3.79868932e-02,  5.58654740e-02,
#        -5.46089597e-02,  6.33850098e-02, -1.04841389e-01, -1.09632805e-01,
#        -4.53496724e-02,  1.09850988e-02, -9.76211671e-03,  1.29171371e-01,
#         2.42608767e-02,  9.02588293e-03, -1.19516782e-01,  5.00722708e-05,
#         8.14301372e-02, -3.65579501e-02, -2.43082568e-02, -9.90865454e-02,
#        -2.58748438e-02,  3.38563286e-02,  2.65326835e-02, -4.00744677e-02,
#         2.93343049e-02,  2.01547444e-02,  4.89204191e-02,  4.24658693e-02,
#         5.04892925e-03,  8.12752023e-02,  4.25269306e-02,  1.10281646e-01,
#         6.71671703e-02, -6.07213229e-02, -7.86910057e-02,  6.65010959e-02],
#       dtype=float32)

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ### Splitting the dataset

# %%
X = embedding_matrix
y = data["Sentiment"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (753, 384) (252, 384)

# %%
print(y_train.shape, y_test.shape)
# Out:
# (753,) (252,)

# %% [markdown]
# ## Model Building - Transformers + ML

# %%
# creating a function to plot the confusion matrix
def plot_confusion_matrix(actual, predicted):
    cm = confusion_matrix(actual, predicted)

    plt.figure(figsize = (5, 4))
    label_list = ['Negative', 'Neutral', 'Positive']
    sns.heatmap(cm, annot = True,  fmt = '.0f', xticklabels = label_list, yticklabels = label_list)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %%
# Building the model
rf_transformer = RandomForestClassifier(n_estimators = 100, max_depth = 7, random_state = 42)

# Fitting on train data
rf_transformer.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=7, random_state=42)

# %%
# Predicting on train data
y_pred_train = rf_transformer.predict(X_train)

# Predicting on test data
y_pred_test = rf_transformer.predict(X_test)

# %% [markdown]
# **Train Data**

# %%
plot_confusion_matrix(y_train, y_pred_train)

# %%
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#     NEGATIVE       1.00      0.55      0.71        51
#      NEUTRAL       1.00      0.31      0.48        70
#     POSITIVE       0.90      1.00      0.95       632
#
#     accuracy                           0.91       753
#    macro avg       0.97      0.62      0.71       753
# weighted avg       0.92      0.91      0.89       753

# %% [markdown]
# **Test Data**

# %%
plot_confusion_matrix(y_test, y_pred_test)

# %%
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#     NEGATIVE       1.00      0.09      0.16        23
#      NEUTRAL       1.00      0.18      0.31        11
#     POSITIVE       0.88      1.00      0.94       218
#
#     accuracy                           0.88       252
#    macro avg       0.96      0.42      0.47       252
# weighted avg       0.90      0.88      0.84       252

# %% [markdown]
# ## Model Building - Pre-Trained Transformers

# %% [markdown]
# ### **DistilBERT**

# %%
sentiment_hf = pipeline("sentiment-analysis") # this uses the HF default sentiment analysis model
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
trial_data = ["Love it! The Product is fantastic—sleek design, top-notch quality, and it exceeded my expectations. Highly recommended!"]
sentiment_hf(trial_data)
# Out:
# [{'label': 'POSITIVE', 'score': 0.999884843826294}]

# %%
hf_review_dict = sentiment_hf(data['Product Review'].to_list(),truncation=True) # very long reviews will be truncated to 512 tokens...which isn't great!

# %%
hf_review_dict
# Out:
# [{'label': 'POSITIVE', 'score': 0.9869409203529358},
#  {'label': 'POSITIVE', 'score': 0.9922477006912231},
#  {'label': 'POSITIVE', 'score': 0.9980818033218384},
#  {'label': 'NEGATIVE', 'score': 0.9911579489707947},
#  {'label': 'POSITIVE', 'score': 0.9949508905410767},
#  {'label': 'POSITIVE', 'score': 0.9964650869369507},
#  {'label': 'NEGATIVE', 'score': 0.9404022097587585},
#  {'label': 'POSITIVE', 'score': 0.981304943561554},
#  {'label': 'NEGATIVE', 'score': 0.7891666889190674},
#  {'label': 'POSITIVE', 'score': 0.9998672008514404},
#  {'label': 'NEGATIVE', 'score': 0.868466854095459},
#  {'label': 'POSITIVE', 'score': 0.9742205739021301},
#  {'label': 'POSITIVE', 'score': 0.9992486834526062},
#  {'label': 'POSITIVE', 'score': 0.9997641444206238},
#  {'label': 'POSITIVE', 'score': 0.9997361302375793},
#  {'label': 'POSITIVE', 'score': 0.9700966477394104},
#  {'label': 'POSITIVE', 'score': 0.9718190431594849},
#  {'label': 'NEGATIVE', 'score': 0.9256631731987},
#  {'label': 'POSITIVE', 'score': 0.9324641823768616},
#  {'label': 'POSITIVE', 'score': 0.9549436569213867},
#  {'label': 'POSITIVE', 'score': 0.9987743496894836},
#  {'label': 'POSITIVE', 'score': 0.9921849370002747},
#  {'label': 'POSITIVE', 'score': 0.9868659377098083},
#  {'label': 'POSITIVE', 'score': 0.9979876279830933},
#  {'label': 'NEGATIVE', 'score': 0.9977263808250427},
#  {'label': 'POSITIVE', 'score': 0.9967363476753235},
#  {'label': 'POSITIVE', 'score': 0.9958673715591431},
#  {'label': 'POSITIVE', 'score': 0.9711541533470154},
#  {'label': 'POSITIVE', 'score': 0.9997138381004333},
#  {'label': 'POSITIVE', 'score': 0.9979973435401917},
#  {'label': 'NEGATIVE', 'score': 0.7403566837310791},
#  {'label': 'POSITIVE', 'score': 0.9791429042816162},
#  {'label': 'NEGATIVE', 'score': 0.9988933205604553},
#  {'label': 'POSITIVE', 'score': 0.996641993522644},
#  {'label': 'POSITIVE', 'score': 0.9866514205932617},
#  {'label': 'NEGATIVE', 'score': 0.998140811920166},
#  {'label': 'NEGATIVE', 'score': 0.7198483943939209},
#  {'label': 'NEGATIVE', 'score': 0.9997026324272156},
#  {'label': 'NEGATIVE', 'score': 0.9992102384567261},
#  {'label': 'POSITIVE', 'score': 0.98973149061203},
#  {'label': 'POSITIVE', 'score': 0.9868659377098083},
#  {'label': 'POSITIVE', 'score': 0.9979876279830933},
#  {'label': 'NEGATIVE', 'score': 0.9977263808250427},
#  {'label': 'POSITIVE', 'score': 0.9967363476753235},
#  {'label': 'POSITIVE', 'score': 0.9958673715591431},
#  {'label': 'POSITIVE', 'score': 0.9711541533470154},
#  {'label': 'POSITIVE', 'score': 0.9997138381004333},
#  {'label': 'POSITIVE', 'score': 0.9979973435401917},
#  {'label': 'NEGATIVE', 'score': 0.7403566837310791},
#  {'label': 'POSITIVE', 'score': 0.9791429042816162},
#  {'label': 'NEGATIVE', 'score': 0.9988933205604553},
#  {'label': 'POSITIVE', 'score': 0.996641993522644},
#  {'label': 'POSITIVE', 'score': 0.9866514205932617},
#  {'label': 'POSITIVE', 'score': 0.9868659377098083},
#  {'label': 'POSITIVE', 'score': 0.9979876279830933},
#  {'label': 'NEGATIVE', 'score': 0.9977263808250427},
#  {'label': 'POSITIVE', 'score': 0.9967363476753235},
#  {'label': 'POSITIVE', 'score': 0.9958673715591431},
#  {'label': 'POSITIVE', 'score': 0.9711541533470154},
#  {'label': 'POSITIVE', 'score': 0.9997138381004333},
#  {'label': 'POSITIVE', 'score': 0.9979973435401917},
#  {'label': 'NEGATIVE', 'score': 0.9968103766441345},
#  {'label': 'NEGATIVE', 'score': 0.9866114854812622},
#  {'label': 'POSITIVE', 'score': 0.998892605304718},
#  {'label': 'POSITIVE', 'score': 0.9995313882827759},
#  {'label': 'POSITIVE', 'score': 0.9972683191299438},
#  {'label': 'NEGATIVE', 'score': 0.9995465874671936},
#  {'label': 'POSITIVE', 'score': 0.9998049139976501},
#  {'label': 'POSITIVE', 'score': 0.9961657524108887},
#  {'label': 'POSITIVE', 'score': 0.858677864074707},
#  {'label': 'NEGATIVE', 'score': 0.9926048517227173},
#  {'label': 'POSITIVE', 'score': 0.8972719311714172},
#  {'label': 'NEGATIVE', 'score': 0.9968103766441345},
#  {'label': 'NEGATIVE', 'score': 0.9866114854812622},
#  {'label': 'POSITIVE', 'score': 0.9972683191299438},
#  {'label': 'POSITIVE', 'score': 0.9995313882827759},
#  {'label': 'POSITIVE', 'score': 0.9998049139976501},
#  {'label': 'POSITIVE', 'score': 0.9994964599609375},
#  {'label': 'NEGATIVE', 'score': 0.9997610449790955},
#  {'label': 'POSITIVE', 'score': 0.9996445178985596},
#  {'label': 'POSITIVE', 'score': 0.998892605304718},
#  {'label': 'POSITIVE', 'score': 0.9996490478515625},
#  {'label': 'NEGATIVE', 'score': 0.9992469549179077},
#  {'label': 'NEGATIVE', 'score': 0.9988933205604553},
#  {'label': 'POSITIVE', 'score': 0.996641993522644},
#  {'label': 'POSITIVE', 'score': 0.9866514205932617},
#  {'label': 'NEGATIVE', 'score': 0.9988933205604553},
#  {'label': 'POSITIVE', 'score': 0.996641993522644},
#  {'label': 'POSITIVE', 'score': 0.9866514205932617},
#  {'label': 'NEGATIVE', 'score': 0.9886476397514343},
#  {'label': 'NEGATIVE', 'score': 0.9968101382255554},
#  {'label': 'NEGATIVE', 'score': 0.996204674243927},
#  {'label': 'NEGATIVE', 'score': 0.9988933205604553},
#  {'label': 'POSITIVE', 'score': 0.996641993522644},
#  {'label': 'POSITIVE', 'score': 0.9866514205932617},
#  {'label': 'POSITIVE', 'score': 0.9974913597106934},
#  {'label': 'NEGATIVE', 'score': 0.9845899343490601},
#  {'label': 'NEGATIVE', 'score': 0.9929088354110718},
#  {'label': 'POSITIVE', 'score': 0.9974913597106934},
#  {'label': 'NEGATIVE', 'score': 0.9845899343490601},
#  {'label': 'NEGATIVE', 'score': 0.9929088354110718},
#  {'label': 'NEGATIVE', 'score': 0.678388237953186},
#  {'label': 'NEGATIVE', 'score': 0.9963411688804626},
#  {'label': 'POSITIVE', 'score': 0.972625732421875},
#  {'label': 'POSITIVE', 'score': 0.910769522190094},
#  {'label': 'POSITIVE', 'score': 0.9868659377098083},
#  {'label': 'POSITIVE', 'score': 0.9979876279830933},
#  {'label': 'NEGATIVE', 'score': 0.9977263808250427},
#  {'label': 'POSITIVE', 'score': 0.9967363476753235},
#  {'label': 'POSITIVE', 'score': 0.9958673715591431},
#  {'label': 'POSITIVE', 'score': 0.9711541533470154},
#  {'label': 'POSITIVE', 'score': 0.9997138381004333},
#  {'label': 'POSITIVE', 'score': 0.9979973435401917},
#  {'label': 'NEGATIVE', 'score': 0.9558490514755249},
#  {'label': 'NEGATIVE', 'score': 0.9534834027290344},
#  {'label': 'NEGATIVE', 'score': 0.9949348568916321},
#  {'label': 'NEGATIVE', 'score': 0.678388237953186},
#  {'label': 'NEGATIVE', 'score': 0.9963411688804626},
#  {'label': 'POSITIVE', 'score': 0.972625732421875},
#  {'label': 'POSITIVE', 'score': 0.910769522190094},
#  {'label': 'NEGATIVE', 'score': 0.9945376515388489},
#  {'label': 'NEGATIVE', 'score': 0.9931439161300659},
#  {'label': 'POSITIVE', 'score': 0.844136655330658},
#  {'label': 'NEGATIVE', 'score': 0.9992075562477112},
#  {'label': 'NEGATIVE', 'score': 0.9994138479232788},
#  {'label': 'POSITIVE', 'score': 0.9754128456115723},
#  {'label': 'NEGATIVE', 'score': 0.982635498046875},
#  {'label': 'POSITIVE', 'score': 0.9784827828407288},
#  {'label': 'NEGATIVE', 'score': 0.999377429485321},
#  {'label': 'NEGATIVE', 'score': 0.9633455872535706},
#  {'label': 'POSITIVE', 'score': 0.9885374307632446},
#  {'label': 'NEGATIVE', 'score': 0.9993682503700256},
#  {'label': 'NEGATIVE', 'score': 0.9969555139541626},
#  {'label': 'NEGATIVE', 'score': 0.6629267334938049},
#  {'label': 'POSITIVE', 'score': 0.941476047039032},
#  {'label': 'NEGATIVE', 'score': 0.9785453081130981},
#  {'label': 'POSITIVE', 'score': 0.9993062019348145},
#  {'label': 'POSITIVE', 'score': 0.9922196865081787},
#  {'label': 'POSITIVE', 'score': 0.9997521042823792},
#  {'label': 'NEGATIVE', 'score': 0.9992769360542297},
#  {'label': 'NEGATIVE', 'score': 0.990760862827301},
#  {'label': 'NEGATIVE', 'score': 0.999498724937439},
#  {'label': 'NEGATIVE', 'score': 0.9191539287567139},
#  {'label': 'NEGATIVE', 'score': 0.9660439491271973},
#  {'label': 'POSITIVE', 'score': 0.9980348944664001},
#  {'label': 'POSITIVE', 'score': 0.9974913597106934},
#  {'label': 'NEGATIVE', 'score': 0.9845899343490601},
#  {'label': 'NEGATIVE', 'score': 0.9929088354110718},
#  {'label': 'POSITIVE', 'score': 0.9974913597106934},
#  {'label': 'NEGATIVE', 'score': 0.9845899343490601},
#  {'label': 'NEGATIVE', 'score': 0.9929088354110718},
#  {'label': 'POSITIVE', 'score': 0.9971178770065308},
#  {'label': 'NEGATIVE', 'score': 0.9912667870521545},
#  {'label': 'NEGATIVE', 'score': 0.9925496578216553},
#  {'label': 'POSITIVE', 'score': 0.9829681515693665},
#  {'label': 'POSITIVE', 'score': 0.8643609285354614},
#  {'label': 'POSITIVE', 'score': 0.5896758437156677},
#  {'label': 'NEGATIVE', 'score': 0.9883755445480347},
#  {'label': 'NEGATIVE', 'score': 0.9963743090629578},
#  {'label': 'POSITIVE', 'score': 0.8165497779846191},
#  {'label': 'NEGATIVE', 'score': 0.996183454990387},
#  {'label': 'POSITIVE', 'score': 0.6662276387214661},
#  {'label': 'POSITIVE', 'score': 0.9668228030204773},
#  {'label': 'NEGATIVE', 'score': 0.9199765920639038},
#  {'label': 'NEGATIVE', 'score': 0.9988402724266052},
#  {'label': 'POSITIVE', 'score': 0.9992903470993042},
#  {'label': 'POSITIVE', 'score': 0.9997020363807678},
#  {'label': 'NEGATIVE', 'score': 0.9191539287567139},
#  {'label': 'NEGATIVE', 'score': 0.9660439491271973},
#  {'label': 'POSITIVE', 'score': 0.9980348944664001},
#  {'label': 'NEGATIVE', 'score': 0.9969639182090759},
#  {'label': 'POSITIVE', 'score': 0.9947797060012817},
#  {'label': 'NEGATIVE', 'score': 0.9434486627578735},
#  {'label': 'POSITIVE', 'score': 0.9998738765716553},
#  {'label': 'POSITIVE', 'score': 0.9976679682731628},
#  {'label': 'POSITIVE', 'score': 0.9843655824661255},
#  {'label': 'POSITIVE', 'score': 0.9987743496894836},
#  {'label': 'POSITIVE', 'score': 0.9921849370002747},
#  {'label': 'POSITIVE', 'score': 0.9549436569213867},
#  {'label': 'POSITIVE', 'score': 0.9324641823768616},
#  {'label': 'POSITIVE', 'score': 0.9997264742851257},
#  {'label': 'POSITIVE', 'score': 0.9986804127693176},
#  {'label': 'POSITIVE', 'score': 0.9998196959495544},
#  {'label': 'POSITIVE', 'score': 0.9879837036132812},
#  {'label': 'POSITIVE', 'score': 0.9706582427024841},
#  {'label': 'NEGATIVE', 'score': 0.9993941783905029},
#  {'label': 'NEGATIVE', 'score': 0.9993828535079956},
#  {'label': 'NEGATIVE', 'score': 0.9979137778282166},
#  {'label': 'POSITIVE', 'score': 0.619447648525238},
#  {'label': 'POSITIVE', 'score': 0.9997568726539612},
#  {'label': 'POSITIVE', 'score': 0.9842064380645752},
#  {'label': 'POSITIVE', 'score': 0.9300499558448792},
#  {'label': 'POSITIVE', 'score': 0.9997788071632385},
#  {'label': 'NEGATIVE', 'score': 0.9973465204238892},
#  {'label': 'POSITIVE', 'score': 0.9973236322402954},
#  {'label': 'NEGATIVE', 'score': 0.999168872833252},
#  {'label': 'POSITIVE', 'score': 0.9182165861129761},
#  {'label': 'NEGATIVE', 'score': 0.9914937019348145},
#  {'label': 'POSITIVE', 'score': 0.9993433356285095},
#  {'label': 'POSITIVE', 'score': 0.985220193862915},
#  {'label': 'POSITIVE', 'score': 0.9998410940170288},
#  {'label': 'POSITIVE', 'score': 0.9780851602554321},
#  {'label': 'POSITIVE', 'score': 0.9996917247772217},
#  {'label': 'POSITIVE', 'score': 0.9969033598899841},
#  {'label': 'POSITIVE', 'score': 0.9920816421508789},
#  {'label': 'POSITIVE', 'score': 0.976882815361023},
#  {'label': 'POSITIVE', 'score': 0.9859243035316467},
#  {'label': 'NEGATIVE', 'score': 0.9996355772018433},
#  {'label': 'POSITIVE', 'score': 0.999882698059082},
#  {'label': 'NEGATIVE', 'score': 0.9975705742835999},
#  {'label': 'POSITIVE', 'score': 0.9752715229988098},
#  {'label': 'NEGATIVE', 'score': 0.9962823987007141},
#  {'label': 'NEGATIVE', 'score': 0.8861449360847473},
#  {'label': 'POSITIVE', 'score': 0.9810959696769714},
#  {'label': 'NEGATIVE', 'score': 0.9995524287223816},
#  {'label': 'NEGATIVE', 'score': 0.9997885823249817},
#  {'label': 'POSITIVE', 'score': 0.9998036026954651},
#  {'label': 'POSITIVE', 'score': 0.9996902942657471},
#  {'label': 'NEGATIVE', 'score': 0.9356569647789001},
#  {'label': 'POSITIVE', 'score': 0.9937164187431335},
#  {'label': 'NEGATIVE', 'score': 0.9994550347328186},
#  {'label': 'NEGATIVE', 'score': 0.9972219467163086},
#  {'label': 'NEGATIVE', 'score': 0.987271249294281},
#  {'label': 'NEGATIVE', 'score': 0.6343082189559937},
#  {'label': 'NEGATIVE', 'score': 0.9981271624565125},
#  {'label': 'POSITIVE', 'score': 0.9995785355567932},
#  {'label': 'POSITIVE', 'score': 0.9998505115509033},
#  {'label': 'POSITIVE', 'score': 0.9991884827613831},
#  {'label': 'POSITIVE', 'score': 0.9908287525177002},
#  {'label': 'NEGATIVE', 'score': 0.9972803592681885},
#  {'label': 'POSITIVE', 'score': 0.999823272228241},
#  {'label': 'POSITIVE', 'score': 0.9760997295379639},
#  {'label': 'NEGATIVE', 'score': 0.9749875068664551},
#  {'label': 'NEGATIVE', 'score': 0.8352525234222412},
#  {'label': 'POSITIVE', 'score': 0.9998409748077393},
#  {'label': 'POSITIVE', 'score': 0.9971480965614319},
#  {'label': 'POSITIVE', 'score': 0.9979963898658752},
#  {'label': 'POSITIVE', 'score': 0.9942506551742554},
#  {'label': 'POSITIVE', 'score': 0.9997847676277161},
#  {'label': 'POSITIVE', 'score': 0.9997037053108215},
#  {'label': 'POSITIVE', 'score': 0.9987971782684326},
#  {'label': 'POSITIVE', 'score': 0.9989383816719055},
#  {'label': 'NEGATIVE', 'score': 0.999113142490387},
#  {'label': 'POSITIVE', 'score': 0.999825656414032},
#  {'label': 'NEGATIVE', 'score': 0.9980757236480713},
#  {'label': 'NEGATIVE', 'score': 0.9997814297676086},
#  {'label': 'POSITIVE', 'score': 0.9992181062698364},
#  {'label': 'NEGATIVE', 'score': 0.9996992349624634},
#  {'label': 'NEGATIVE', 'score': 0.9978153705596924},
#  {'label': 'NEGATIVE', 'score': 0.9939467906951904},
#  {'label': 'POSITIVE', 'score': 0.9992782473564148},
#  {'label': 'NEGATIVE', 'score': 0.9997040629386902},
#  {'label': 'NEGATIVE', 'score': 0.9853706359863281},
#  {'label': 'POSITIVE', 'score': 0.9998282194137573},
#  {'label': 'POSITIVE', 'score': 0.9998688697814941},
#  {'label': 'POSITIVE', 'score': 0.996061384677887},
#  {'label': 'NEGATIVE', 'score': 0.5231807827949524},
#  {'label': 'NEGATIVE', 'score': 0.9831864833831787},
#  {'label': 'POSITIVE', 'score': 0.98853999376297},
#  {'label': 'POSITIVE', 'score': 0.9034443497657776},
#  {'label': 'NEGATIVE', 'score': 0.9997624754905701},
#  {'label': 'POSITIVE', 'score': 0.8058170676231384},
#  {'label': 'POSITIVE', 'score': 0.9230706095695496},
#  {'label': 'NEGATIVE', 'score': 0.9682826399803162},
#  {'label': 'POSITIVE', 'score': 0.8079887628555298},
#  {'label': 'NEGATIVE', 'score': 0.9978734254837036},
#  {'label': 'POSITIVE', 'score': 0.997908353805542},
#  {'label': 'NEGATIVE', 'score': 0.9994226694107056},
#  {'label': 'NEGATIVE', 'score': 0.9954451322555542},
#  {'label': 'POSITIVE', 'score': 0.9964544773101807},
#  {'label': 'NEGATIVE', 'score': 0.9976685643196106},
#  {'label': 'NEGATIVE', 'score': 0.9971605539321899},
#  {'label': 'NEGATIVE', 'score': 0.9979876279830933},
#  {'label': 'NEGATIVE', 'score': 0.9932146072387695},
#  {'label': 'POSITIVE', 'score': 0.9911942481994629},
#  {'label': 'NEGATIVE', 'score': 0.9223539233207703},
#  {'label': 'POSITIVE', 'score': 0.9993391633033752},
#  {'label': 'NEGATIVE', 'score': 0.9941046833992004},
#  {'label': 'POSITIVE', 'score': 0.9641570448875427},
#  {'label': 'NEGATIVE', 'score': 0.9967830181121826},
#  {'label': 'POSITIVE', 'score': 0.99965500831604},
#  {'label': 'POSITIVE', 'score': 0.9997320771217346},
#  {'label': 'POSITIVE', 'score': 0.9998019337654114},
#  {'label': 'NEGATIVE', 'score': 0.9877299666404724},
#  {'label': 'POSITIVE', 'score': 0.9997366070747375},
#  {'label': 'POSITIVE', 'score': 0.9995759129524231},
#  {'label': 'POSITIVE', 'score': 0.9998682737350464},
#  {'label': 'POSITIVE', 'score': 0.9998161196708679},
#  {'label': 'POSITIVE', 'score': 0.9998366832733154},
#  {'label': 'NEGATIVE', 'score': 0.960759699344635},
#  {'label': 'NEGATIVE', 'score': 0.9972954392433167},
#  {'label': 'NEGATIVE', 'score': 0.999752938747406},
#  {'label': 'POSITIVE', 'score': 0.992838442325592},
#  {'label': 'NEGATIVE', 'score': 0.9987003803253174},
#  {'label': 'POSITIVE', 'score': 0.9981006979942322},
#  {'label': 'POSITIVE', 'score': 0.7297723889350891},
#  {'label': 'NEGATIVE', 'score': 0.5419577956199646},
#  {'label': 'POSITIVE', 'score': 0.9979115128517151},
#  {'label': 'POSITIVE', 'score': 0.9753572940826416},
#  {'label': 'NEGATIVE', 'score': 0.8911496996879578},
#  {'label': 'POSITIVE', 'score': 0.9868659377098083},
#  {'label': 'POSITIVE', 'score': 0.9979876279830933},
#  {'label': 'NEGATIVE', 'score': 0.9977263808250427},
#  {'label': 'POSITIVE', 'score': 0.9967363476753235},
#  {'label': 'POSITIVE', 'score': 0.9958673715591431},
#  {'label': 'POSITIVE', 'score': 0.9711541533470154},
#  {'label': 'POSITIVE', 'score': 0.9997138381004333},
#  {'label': 'POSITIVE', 'score': 0.9979973435401917},
#  {'label': 'POSITIVE', 'score': 0.9791429042816162},
#  {'label': 'NEGATIVE', 'score': 0.7403566837310791},
#  {'label': 'POSITIVE', 'score': 0.9997846484184265},
#  {'label': 'POSITIVE', 'score': 0.9994656443595886},
#  {'label': 'POSITIVE', 'score': 0.999756395816803},
#  {'label': 'POSITIVE', 'score': 0.9996428489685059},
#  {'label': 'POSITIVE', 'score': 0.9998517036437988},
#  {'label': 'POSITIVE', 'score': 0.9998000264167786},
#  {'label': 'POSITIVE', 'score': 0.9993877410888672},
#  {'label': 'POSITIVE', 'score': 0.9997867941856384},
#  {'label': 'POSITIVE', 'score': 0.9998117089271545},
#  {'label': 'POSITIVE', 'score': 0.9997989535331726},
#  {'label': 'POSITIVE', 'score': 0.9998767375946045},
#  {'label': 'POSITIVE', 'score': 0.9996273517608643},
#  {'label': 'NEGATIVE', 'score': 0.9984398484230042},
#  {'label': 'POSITIVE', 'score': 0.9863938689231873},
#  {'label': 'NEGATIVE', 'score': 0.6825552582740784},
#  {'label': 'POSITIVE', 'score': 0.5952547192573547},
#  {'label': 'POSITIVE', 'score': 0.9803046584129333},
#  {'label': 'POSITIVE', 'score': 0.9814922213554382},
#  {'label': 'NEGATIVE', 'score': 0.578713059425354},
#  {'label': 'NEGATIVE', 'score': 0.9994930028915405},
#  {'label': 'POSITIVE', 'score': 0.9947518706321716},
#  {'label': 'POSITIVE', 'score': 0.9997434020042419},
#  {'label': 'POSITIVE', 'score': 0.9994988441467285},
#  {'label': 'NEGATIVE', 'score': 0.9995243549346924},
#  {'label': 'NEGATIVE', 'score': 0.9338247179985046},
#  {'label': 'POSITIVE', 'score': 0.9868659377098083},
#  {'label': 'POSITIVE', 'score': 0.9979876279830933},
#  {'label': 'NEGATIVE', 'score': 0.9977263808250427},
#  {'label': 'POSITIVE', 'score': 0.9967363476753235},
#  {'label': 'POSITIVE', 'score': 0.9958673715591431},
#  {'label': 'POSITIVE', 'score': 0.9711541533470154},
#  {'label': 'POSITIVE', 'score': 0.9997138381004333},
#  {'label': 'POSITIVE', 'score': 0.9979973435401917},
#  {'label': 'NEGATIVE', 'score': 0.7403566837310791},
#  {'label': 'POSITIVE', 'score': 0.9791429042816162},
#  {'label': 'POSITIVE', 'score': 0.9907544851303101},
#  {'label': 'POSITIVE', 'score': 0.969780683517456},
#  {'label': 'NEGATIVE', 'score': 0.9365267753601074},
#  {'label': 'NEGATIVE', 'score': 0.9823501110076904},
#  {'label': 'POSITIVE', 'score': 0.9996206760406494},
#  {'label': 'NEGATIVE', 'score': 0.64829021692276},
#  {'label': 'POSITIVE', 'score': 0.9982873797416687},
#  {'label': 'POSITIVE', 'score': 0.99904865026474},
#  {'label': 'NEGATIVE', 'score': 0.9808797240257263},
#  {'label': 'POSITIVE', 'score': 0.9984034895896912},
#  {'label': 'POSITIVE', 'score': 0.8574923872947693},
#  {'label': 'NEGATIVE', 'score': 0.9992456436157227},
#  {'label': 'NEGATIVE', 'score': 0.5940282344818115},
#  {'label': 'POSITIVE', 'score': 0.9977750182151794},
#  {'label': 'POSITIVE', 'score': 0.9984143972396851},
#  {'label': 'POSITIVE', 'score': 0.9967875480651855},
#  {'label': 'NEGATIVE', 'score': 0.992734432220459},
#  {'label': 'NEGATIVE', 'score': 0.989534318447113},
#  {'label': 'POSITIVE', 'score': 0.987282395362854},
#  {'label': 'NEGATIVE', 'score': 0.9608425498008728},
#  {'label': 'POSITIVE', 'score': 0.9997079968452454},
#  {'label': 'POSITIVE', 'score': 0.668291449546814},
#  {'label': 'NEGATIVE', 'score': 0.7822116017341614},
#  {'label': 'NEGATIVE', 'score': 0.9931522607803345},
#  {'label': 'POSITIVE', 'score': 0.9718739986419678},
#  {'label': 'NEGATIVE', 'score': 0.7086468935012817},
#  {'label': 'NEGATIVE', 'score': 0.9962902069091797},
#  {'label': 'POSITIVE', 'score': 0.86998450756073},
#  {'label': 'POSITIVE', 'score': 0.8401620388031006},
#  {'label': 'NEGATIVE', 'score': 0.8524733781814575},
#  {'label': 'POSITIVE', 'score': 0.9995321035385132},
#  {'label': 'NEGATIVE', 'score': 0.6948267817497253},
#  {'label': 'POSITIVE', 'score': 0.995345413684845},
#  {'label': 'POSITIVE', 'score': 0.970325231552124},
#  {'label': 'POSITIVE', 'score': 0.9977750182151794},
#  {'label': 'POSITIVE', 'score': 0.9984143972396851},
#  {'label': 'POSITIVE', 'score': 0.9967875480651855},
#  {'label': 'NEGATIVE', 'score': 0.9824658632278442},
#  {'label': 'POSITIVE', 'score': 0.9678009152412415},
#  {'label': 'NEGATIVE', 'score': 0.9153372049331665},
#  {'label': 'POSITIVE', 'score': 0.9998586177825928},
#  {'label': 'NEGATIVE', 'score': 0.9934358596801758},
#  {'label': 'NEGATIVE', 'score': 0.8132099509239197},
#  {'label': 'NEGATIVE', 'score': 0.9011916518211365},
#  {'label': 'POSITIVE', 'score': 0.9879837036132812},
#  {'label': 'NEGATIVE', 'score': 0.8132099509239197},
#  {'label': 'NEGATIVE', 'score': 0.9011916518211365},
#  {'label': 'POSITIVE', 'score': 0.9893475770950317},
#  {'label': 'POSITIVE', 'score': 0.8063822984695435},
#  {'label': 'POSITIVE', 'score': 0.9907324314117432},
#  {'label': 'POSITIVE', 'score': 0.9959779381752014},
#  {'label': 'POSITIVE', 'score': 0.9661227464675903},
#  {'label': 'POSITIVE', 'score': 0.9973702430725098},
#  {'label': 'POSITIVE', 'score': 0.999833345413208},
#  {'label': 'POSITIVE', 'score': 0.9992184638977051},
#  {'label': 'POSITIVE', 'score': 0.9988191723823547},
#  {'label': 'POSITIVE', 'score': 0.9995771050453186},
#  {'label': 'POSITIVE', 'score': 0.9987820982933044},
#  {'label': 'POSITIVE', 'score': 0.999854564666748},
#  {'label': 'POSITIVE', 'score': 0.9992664456367493},
#  {'label': 'POSITIVE', 'score': 0.9997380375862122},
#  {'label': 'POSITIVE', 'score': 0.999581515789032},
#  {'label': 'NEGATIVE', 'score': 0.9981420040130615},
#  {'label': 'POSITIVE', 'score': 0.9944642186164856},
#  {'label': 'POSITIVE', 'score': 0.9974645376205444},
#  {'label': 'POSITIVE', 'score': 0.9430354833602905},
#  {'label': 'POSITIVE', 'score': 0.9998422861099243},
#  {'label': 'POSITIVE', 'score': 0.9997227787971497},
#  {'label': 'POSITIVE', 'score': 0.9998766183853149},
#  {'label': 'POSITIVE', 'score': 0.9986401200294495},
#  {'label': 'POSITIVE', 'score': 0.9992972612380981},
#  {'label': 'NEGATIVE', 'score': 0.8426299691200256},
#  {'label': 'POSITIVE', 'score': 0.9942895174026489},
#  {'label': 'POSITIVE', 'score': 0.9998587369918823},
#  {'label': 'NEGATIVE', 'score': 0.9942067861557007},
#  {'label': 'POSITIVE', 'score': 0.9962434768676758},
#  {'label': 'POSITIVE', 'score': 0.9998088479042053},
#  {'label': 'NEGATIVE', 'score': 0.9987241625785828},
#  {'label': 'POSITIVE', 'score': 0.9994345307350159},
#  {'label': 'NEGATIVE', 'score': 0.9995986819267273},
#  {'label': 'NEGATIVE', 'score': 0.9765591621398926},
#  {'label': 'POSITIVE', 'score': 0.9995760321617126},
#  {'label': 'POSITIVE', 'score': 0.7919800281524658},
#  {'label': 'POSITIVE', 'score': 0.9996508359909058},
#  {'label': 'POSITIVE', 'score': 0.9865744709968567},
#  {'label': 'NEGATIVE', 'score': 0.9994745850563049},
#  {'label': 'POSITIVE', 'score': 0.9998499155044556},
#  {'label': 'POSITIVE', 'score': 0.9998778104782104},
#  {'label': 'POSITIVE', 'score': 0.9998691082000732},
#  {'label': 'POSITIVE', 'score': 0.9994844198226929},
#  {'label': 'POSITIVE', 'score': 0.7868715524673462},
#  {'label': 'POSITIVE', 'score': 0.9984769225120544},
#  {'label': 'POSITIVE', 'score': 0.9998339414596558},
#  {'label': 'POSITIVE', 'score': 0.9998805522918701},
#  {'label': 'POSITIVE', 'score': 0.9995218515396118},
#  {'label': 'POSITIVE', 'score': 0.9945917725563049},
#  {'label': 'POSITIVE', 'score': 0.9902599453926086},
#  {'label': 'POSITIVE', 'score': 0.9959053993225098},
#  {'label': 'POSITIVE', 'score': 0.9997029900550842},
#  {'label': 'POSITIVE', 'score': 0.9669966697692871},
#  {'label': 'POSITIVE', 'score': 0.9410998225212097},
#  {'label': 'POSITIVE', 'score': 0.9974644184112549},
#  {'label': 'POSITIVE', 'score': 0.9998852014541626},
#  {'label': 'NEGATIVE', 'score': 0.9985036849975586},
#  {'label': 'POSITIVE', 'score': 0.9994930028915405},
#  {'label': 'POSITIVE', 'score': 0.9998569488525391},
#  {'label': 'POSITIVE', 'score': 0.978410542011261},
#  {'label': 'POSITIVE', 'score': 0.9979954957962036},
#  {'label': 'POSITIVE', 'score': 0.9998036026954651},
#  {'label': 'POSITIVE', 'score': 0.9998599290847778},
#  {'label': 'POSITIVE', 'score': 0.9997394680976868},
#  {'label': 'POSITIVE', 'score': 0.9997764229774475},
#  {'label': 'POSITIVE', 'score': 0.9998165965080261},
#  {'label': 'POSITIVE', 'score': 0.9995254278182983},
#  {'label': 'POSITIVE', 'score': 0.9997557997703552},
#  {'label': 'NEGATIVE', 'score': 0.9970567226409912},
#  {'label': 'POSITIVE', 'score': 0.9998841285705566},
#  {'label': 'NEGATIVE', 'score': 0.9642131328582764},
#  {'label': 'POSITIVE', 'score': 0.9983547329902649},
#  {'label': 'POSITIVE', 'score': 0.9998834133148193},
#  {'label': 'NEGATIVE', 'score': 0.9705501794815063},
#  {'label': 'POSITIVE', 'score': 0.9998519420623779},
#  {'label': 'POSITIVE', 'score': 0.9995617270469666},
#  {'label': 'POSITIVE', 'score': 0.9998809099197388},
#  {'label': 'POSITIVE', 'score': 0.9998307228088379},
#  {'label': 'POSITIVE', 'score': 0.9994476437568665},
#  {'label': 'NEGATIVE', 'score': 0.9955099821090698},
#  {'label': 'POSITIVE', 'score': 0.9942097663879395},
#  {'label': 'NEGATIVE', 'score': 0.8595194220542908},
#  {'label': 'POSITIVE', 'score': 0.9998807907104492},
#  {'label': 'POSITIVE', 'score': 0.9988579750061035},
#  {'label': 'POSITIVE', 'score': 0.9990921020507812},
#  {'label': 'NEGATIVE', 'score': 0.9460374712944031},
#  {'label': 'POSITIVE', 'score': 0.9345366954803467},
#  {'label': 'POSITIVE', 'score': 0.9970478415489197},
#  {'label': 'POSITIVE', 'score': 0.9998226761817932},
#  {'label': 'NEGATIVE', 'score': 0.9993711113929749},
#  {'label': 'NEGATIVE', 'score': 0.7898554801940918},
#  {'label': 'POSITIVE', 'score': 0.999866247177124},
#  {'label': 'POSITIVE', 'score': 0.9998667240142822},
#  {'label': 'NEGATIVE', 'score': 0.818152129650116},
#  {'label': 'NEGATIVE', 'score': 0.9994789958000183},
#  {'label': 'POSITIVE', 'score': 0.9987121820449829},
#  {'label': 'POSITIVE', 'score': 0.9970550537109375},
#  {'label': 'POSITIVE', 'score': 0.9996277093887329},
#  {'label': 'POSITIVE', 'score': 0.9792348146438599},
#  {'label': 'NEGATIVE', 'score': 0.9914036393165588},
#  {'label': 'POSITIVE', 'score': 0.9988006353378296},
#  {'label': 'POSITIVE', 'score': 0.9996358156204224},
#  {'label': 'POSITIVE', 'score': 0.9958174824714661},
#  {'label': 'POSITIVE', 'score': 0.9923545122146606},
#  {'label': 'POSITIVE', 'score': 0.9995492100715637},
#  {'label': 'POSITIVE', 'score': 0.9997599720954895},
#  {'label': 'POSITIVE', 'score': 0.9128834009170532},
#  {'label': 'POSITIVE', 'score': 0.9923223853111267},
#  {'label': 'POSITIVE', 'score': 0.9954470992088318},
#  {'label': 'POSITIVE', 'score': 0.9998459815979004},
#  {'label': 'POSITIVE', 'score': 0.999543309211731},
#  {'label': 'POSITIVE', 'score': 0.9930195212364197},
#  {'label': 'NEGATIVE', 'score': 0.9997345805168152},
#  {'label': 'POSITIVE', 'score': 0.9998838901519775},
#  {'label': 'POSITIVE', 'score': 0.9997859597206116},
#  {'label': 'NEGATIVE', 'score': 0.9891720414161682},
#  {'label': 'POSITIVE', 'score': 0.9998854398727417},
#  {'label': 'POSITIVE', 'score': 0.9998617172241211},
#  {'label': 'POSITIVE', 'score': 0.9996933937072754},
#  {'label': 'POSITIVE', 'score': 0.9996641874313354},
#  {'label': 'POSITIVE', 'score': 0.9990744590759277},
#  {'label': 'NEGATIVE', 'score': 0.9939596652984619},
#  {'label': 'POSITIVE', 'score': 0.9998701810836792},
#  {'label': 'POSITIVE', 'score': 0.9848708510398865},
#  {'label': 'POSITIVE', 'score': 0.9997350573539734},
#  {'label': 'POSITIVE', 'score': 0.9998825788497925},
#  {'label': 'POSITIVE', 'score': 0.9997627139091492},
#  {'label': 'NEGATIVE', 'score': 0.9910049438476562},
#  {'label': 'POSITIVE', 'score': 0.999825656414032},
#  {'label': 'POSITIVE', 'score': 0.99909508228302},
#  {'label': 'POSITIVE', 'score': 0.9957245588302612},
#  {'label': 'POSITIVE', 'score': 0.9997619986534119},
#  {'label': 'POSITIVE', 'score': 0.9997335076332092},
#  {'label': 'POSITIVE', 'score': 0.9995170831680298},
#  {'label': 'NEGATIVE', 'score': 0.9848015904426575},
#  {'label': 'POSITIVE', 'score': 0.8540679812431335},
#  {'label': 'POSITIVE', 'score': 0.9994021654129028},
#  {'label': 'POSITIVE', 'score': 0.9735575318336487},
#  {'label': 'POSITIVE', 'score': 0.9998723268508911},
#  {'label': 'POSITIVE', 'score': 0.9997432827949524},
#  {'label': 'POSITIVE', 'score': 0.9998846054077148},
#  {'label': 'POSITIVE', 'score': 0.9998225569725037},
#  {'label': 'NEGATIVE', 'score': 0.986883819103241},
#  {'label': 'POSITIVE', 'score': 0.9980260133743286},
#  {'label': 'POSITIVE', 'score': 0.9888647794723511},
#  {'label': 'POSITIVE', 'score': 0.9938643574714661},
#  {'label': 'POSITIVE', 'score': 0.9997487664222717},
#  {'label': 'POSITIVE', 'score': 0.9997679591178894},
#  {'label': 'POSITIVE', 'score': 0.9998772144317627},
#  {'label': 'POSITIVE', 'score': 0.9985270500183105},
#  {'label': 'POSITIVE', 'score': 0.9973799586296082},
#  {'label': 'POSITIVE', 'score': 0.9992491602897644},
#  {'label': 'POSITIVE', 'score': 0.9998792409896851},
#  {'label': 'POSITIVE', 'score': 0.999854564666748},
#  {'label': 'NEGATIVE', 'score': 0.9995216131210327},
#  {'label': 'POSITIVE', 'score': 0.9995483756065369},
#  {'label': 'NEGATIVE', 'score': 0.9977808594703674},
#  {'label': 'POSITIVE', 'score': 0.9998251795768738},
#  {'label': 'POSITIVE', 'score': 0.9997345805168152},
#  {'label': 'NEGATIVE', 'score': 0.9758822917938232},
#  {'label': 'POSITIVE', 'score': 0.9997844099998474},
#  {'label': 'POSITIVE', 'score': 0.9998243451118469},
#  {'label': 'POSITIVE', 'score': 0.9996458292007446},
#  {'label': 'POSITIVE', 'score': 0.9996745586395264},
#  {'label': 'POSITIVE', 'score': 0.9995368719100952},
#  {'label': 'POSITIVE', 'score': 0.9739803075790405},
#  {'label': 'POSITIVE', 'score': 0.9997842907905579},
#  {'label': 'POSITIVE', 'score': 0.9998610019683838},
#  {'label': 'POSITIVE', 'score': 0.9998574256896973},
#  {'label': 'POSITIVE', 'score': 0.9989297986030579},
#  {'label': 'POSITIVE', 'score': 0.9913027286529541},
#  {'label': 'POSITIVE', 'score': 0.9895538091659546},
#  {'label': 'POSITIVE', 'score': 0.999843955039978},
#  {'label': 'POSITIVE', 'score': 0.996077835559845},
#  {'label': 'NEGATIVE', 'score': 0.998275876045227},
#  {'label': 'NEGATIVE', 'score': 0.9937263131141663},
#  {'label': 'POSITIVE', 'score': 0.9941164255142212},
#  {'label': 'POSITIVE', 'score': 0.5617095828056335},
#  {'label': 'POSITIVE', 'score': 0.9997066855430603},
#  {'label': 'POSITIVE', 'score': 0.9640801548957825},
#  {'label': 'POSITIVE', 'score': 0.9998723268508911},
#  {'label': 'NEGATIVE', 'score': 0.9997701048851013},
#  {'label': 'POSITIVE', 'score': 0.9996115565299988},
#  {'label': 'POSITIVE', 'score': 0.9998816251754761},
#  {'label': 'POSITIVE', 'score': 0.999861478805542},
#  {'label': 'POSITIVE', 'score': 0.9998767375946045},
#  {'label': 'NEGATIVE', 'score': 0.9711104035377502},
#  {'label': 'NEGATIVE', 'score': 0.9993478655815125},
#  {'label': 'POSITIVE', 'score': 0.999893069267273},
#  {'label': 'POSITIVE', 'score': 0.9998492002487183},
#  {'label': 'POSITIVE', 'score': 0.9998217225074768},
#  {'label': 'POSITIVE', 'score': 0.9997285008430481},
#  {'label': 'POSITIVE', 'score': 0.9997190833091736},
#  {'label': 'NEGATIVE', 'score': 0.9849022030830383},
#  {'label': 'POSITIVE', 'score': 0.9994588494300842},
#  {'label': 'POSITIVE', 'score': 0.9998220801353455},
#  {'label': 'POSITIVE', 'score': 0.9946893453598022},
#  {'label': 'POSITIVE', 'score': 0.9998494386672974},
#  {'label': 'POSITIVE', 'score': 0.998737633228302},
#  {'label': 'POSITIVE', 'score': 0.9998743534088135},
#  {'label': 'POSITIVE', 'score': 0.9998688697814941},
#  {'label': 'POSITIVE', 'score': 0.9998792409896851},
#  {'label': 'NEGATIVE', 'score': 0.983183741569519},
#  {'label': 'POSITIVE', 'score': 0.9990367889404297},
#  {'label': 'POSITIVE', 'score': 0.9997323155403137},
#  {'label': 'POSITIVE', 'score': 0.9995040893554688},
#  {'label': 'POSITIVE', 'score': 0.9729322195053101},
#  {'label': 'POSITIVE', 'score': 0.9958562254905701},
#  {'label': 'POSITIVE', 'score': 0.9991632699966431},
#  {'label': 'POSITIVE', 'score': 0.9998366832733154},
#  {'label': 'POSITIVE', 'score': 0.9995183944702148},
#  {'label': 'NEGATIVE', 'score': 0.9786918759346008},
#  {'label': 'POSITIVE', 'score': 0.9998854398727417},
#  {'label': 'POSITIVE', 'score': 0.9938452839851379},
#  {'label': 'POSITIVE', 'score': 0.999886155128479},
#  {'label': 'POSITIVE', 'score': 0.9995881915092468},
#  {'label': 'NEGATIVE', 'score': 0.998961329460144},
#  {'label': 'POSITIVE', 'score': 0.9997287392616272},
#  {'label': 'POSITIVE', 'score': 0.9998595714569092},
#  {'label': 'NEGATIVE', 'score': 0.988997757434845},
#  {'label': 'POSITIVE', 'score': 0.9996151924133301},
#  {'label': 'POSITIVE', 'score': 0.9998800754547119},
#  {'label': 'POSITIVE', 'score': 0.999862551689148},
#  {'label': 'POSITIVE', 'score': 0.9998076558113098},
#  {'label': 'POSITIVE', 'score': 0.9998050332069397},
#  {'label': 'POSITIVE', 'score': 0.9997001886367798},
#  {'label': 'POSITIVE', 'score': 0.9970598816871643},
#  {'label': 'POSITIVE', 'score': 0.9998682737350464},
#  {'label': 'POSITIVE', 'score': 0.9998801946640015},
#  {'label': 'POSITIVE', 'score': 0.9998238682746887},
#  {'label': 'POSITIVE', 'score': 0.9005237817764282},
#  {'label': 'POSITIVE', 'score': 0.7975403070449829},
#  {'label': 'POSITIVE', 'score': 0.9997105002403259},
#  {'label': 'NEGATIVE', 'score': 0.9884710311889648},
#  {'label': 'POSITIVE', 'score': 0.9996991157531738},
#  {'label': 'POSITIVE', 'score': 0.999849796295166},
#  {'label': 'POSITIVE', 'score': 0.9998310804367065},
#  {'label': 'POSITIVE', 'score': 0.9990645051002502},
#  {'label': 'POSITIVE', 'score': 0.9998618364334106},
#  {'label': 'NEGATIVE', 'score': 0.9996782541275024},
#  {'label': 'NEGATIVE', 'score': 0.9715585112571716},
#  {'label': 'POSITIVE', 'score': 0.9998109936714172},
#  {'label': 'POSITIVE', 'score': 0.9973180890083313},
#  {'label': 'POSITIVE', 'score': 0.9977045655250549},
#  {'label': 'POSITIVE', 'score': 0.9997487664222717},
#  {'label': 'NEGATIVE', 'score': 0.998347282409668},
#  {'label': 'POSITIVE', 'score': 0.9997351765632629},
#  {'label': 'POSITIVE', 'score': 0.9998047947883606},
#  {'label': 'POSITIVE', 'score': 0.9998836517333984},
#  {'label': 'NEGATIVE', 'score': 0.9988100528717041},
#  {'label': 'POSITIVE', 'score': 0.998090922832489},
#  {'label': 'POSITIVE', 'score': 0.9931496977806091},
#  {'label': 'POSITIVE', 'score': 0.9998493194580078},
#  {'label': 'POSITIVE', 'score': 0.9997715353965759},
#  {'label': 'POSITIVE', 'score': 0.9997323155403137},
#  {'label': 'POSITIVE', 'score': 0.9996153116226196},
#  {'label': 'POSITIVE', 'score': 0.6663240790367126},
#  {'label': 'POSITIVE', 'score': 0.9969407916069031},
#  {'label': 'POSITIVE', 'score': 0.9994267225265503},
#  {'label': 'NEGATIVE', 'score': 0.9785812497138977},
#  {'label': 'POSITIVE', 'score': 0.9998371601104736},
#  {'label': 'POSITIVE', 'score': 0.9998748302459717},
#  {'label': 'POSITIVE', 'score': 0.6213600039482117},
#  {'label': 'POSITIVE', 'score': 0.9979076385498047},
#  {'label': 'POSITIVE', 'score': 0.999265730381012},
#  {'label': 'POSITIVE', 'score': 0.9972162246704102},
#  {'label': 'POSITIVE', 'score': 0.9989272952079773},
#  {'label': 'POSITIVE', 'score': 0.9274757504463196},
#  {'label': 'POSITIVE', 'score': 0.9998691082000732},
#  {'label': 'POSITIVE', 'score': 0.9628246426582336},
#  {'label': 'POSITIVE', 'score': 0.9998252987861633},
#  {'label': 'POSITIVE', 'score': 0.9998284578323364},
#  {'label': 'NEGATIVE', 'score': 0.9989570379257202},
#  {'label': 'NEGATIVE', 'score': 0.999555766582489},
#  {'label': 'POSITIVE', 'score': 0.9274115562438965},
#  {'label': 'NEGATIVE', 'score': 0.9867506623268127},
#  {'label': 'POSITIVE', 'score': 0.9995323419570923},
#  {'label': 'POSITIVE', 'score': 0.9981182813644409},
#  {'label': 'POSITIVE', 'score': 0.981982946395874},
#  {'label': 'POSITIVE', 'score': 0.9955328702926636},
#  {'label': 'NEGATIVE', 'score': 0.9769077301025391},
#  {'label': 'POSITIVE', 'score': 0.9997891783714294},
#  {'label': 'POSITIVE', 'score': 0.9983500242233276},
#  {'label': 'POSITIVE', 'score': 0.9997331500053406},
#  {'label': 'POSITIVE', 'score': 0.9998031258583069},
#  {'label': 'POSITIVE', 'score': 0.8030411005020142},
#  {'label': 'POSITIVE', 'score': 0.9988527297973633},
#  {'label': 'POSITIVE', 'score': 0.9998776912689209},
#  {'label': 'POSITIVE', 'score': 0.9998044371604919},
#  {'label': 'POSITIVE', 'score': 0.9991087317466736},
#  {'label': 'POSITIVE', 'score': 0.9998229146003723},
#  {'label': 'NEGATIVE', 'score': 0.9873448014259338},
#  {'label': 'POSITIVE', 'score': 0.9995032548904419},
#  {'label': 'POSITIVE', 'score': 0.9998642206192017},
#  {'label': 'POSITIVE', 'score': 0.9997408986091614},
#  {'label': 'POSITIVE', 'score': 0.9992627501487732},
#  {'label': 'POSITIVE', 'score': 0.9997063279151917},
#  {'label': 'POSITIVE', 'score': 0.9997267127037048},
#  {'label': 'POSITIVE', 'score': 0.9998238682746887},
#  {'label': 'NEGATIVE', 'score': 0.9883841276168823},
#  {'label': 'POSITIVE', 'score': 0.9995937943458557},
#  {'label': 'POSITIVE', 'score': 0.9998639822006226},
#  {'label': 'POSITIVE', 'score': 0.9997932314872742},
#  {'label': 'POSITIVE', 'score': 0.9998824596405029},
#  {'label': 'NEGATIVE', 'score': 0.9958274960517883},
#  {'label': 'POSITIVE', 'score': 0.9994552731513977},
#  {'label': 'POSITIVE', 'score': 0.9992571473121643},
#  {'label': 'NEGATIVE', 'score': 0.9346720576286316},
#  {'label': 'POSITIVE', 'score': 0.9998188614845276},
#  {'label': 'POSITIVE', 'score': 0.9998292922973633},
#  {'label': 'POSITIVE', 'score': 0.9997195601463318},
#  {'label': 'POSITIVE', 'score': 0.999803364276886},
#  {'label': 'POSITIVE', 'score': 0.9958420395851135},
#  {'label': 'POSITIVE', 'score': 0.9997922778129578},
#  {'label': 'POSITIVE', 'score': 0.967143177986145},
#  {'label': 'POSITIVE', 'score': 0.7079939246177673},
#  {'label': 'POSITIVE', 'score': 0.997878909111023},
#  {'label': 'POSITIVE', 'score': 0.9992597699165344},
#  {'label': 'POSITIVE', 'score': 0.9978329539299011},
#  {'label': 'POSITIVE', 'score': 0.9900816082954407},
#  {'label': 'POSITIVE', 'score': 0.9994667172431946},
#  {'label': 'POSITIVE', 'score': 0.9949824810028076},
#  {'label': 'POSITIVE', 'score': 0.9933778643608093},
#  {'label': 'POSITIVE', 'score': 0.9998793601989746},
#  {'label': 'POSITIVE', 'score': 0.999875545501709},
#  {'label': 'POSITIVE', 'score': 0.9995150566101074},
#  {'label': 'POSITIVE', 'score': 0.7434443235397339},
#  {'label': 'POSITIVE', 'score': 0.9998738765716553},
#  {'label': 'POSITIVE', 'score': 0.9995055198669434},
#  {'label': 'NEGATIVE', 'score': 0.9992713332176208},
#  {'label': 'POSITIVE', 'score': 0.9851497411727905},
#  {'label': 'POSITIVE', 'score': 0.9998388290405273},
#  {'label': 'POSITIVE', 'score': 0.999863862991333},
#  {'label': 'POSITIVE', 'score': 0.9998158812522888},
#  {'label': 'POSITIVE', 'score': 0.9998646974563599},
#  {'label': 'POSITIVE', 'score': 0.9887369275093079},
#  {'label': 'POSITIVE', 'score': 0.7129531502723694},
#  {'label': 'POSITIVE', 'score': 0.9996514320373535},
#  {'label': 'POSITIVE', 'score': 0.9986534118652344},
#  {'label': 'POSITIVE', 'score': 0.9981622099876404},
#  {'label': 'POSITIVE', 'score': 0.9903188943862915},
#  {'label': 'POSITIVE', 'score': 0.9991426467895508},
#  {'label': 'NEGATIVE', 'score': 0.98529052734375},
#  {'label': 'POSITIVE', 'score': 0.9994351267814636},
#  {'label': 'POSITIVE', 'score': 0.9938158988952637},
#  {'label': 'POSITIVE', 'score': 0.9997149109840393},
#  {'label': 'NEGATIVE', 'score': 0.8599127531051636},
#  {'label': 'POSITIVE', 'score': 0.9471323490142822},
#  {'label': 'POSITIVE', 'score': 0.9998125433921814},
#  {'label': 'POSITIVE', 'score': 0.9994208812713623},
#  {'label': 'POSITIVE', 'score': 0.999782145023346},
#  {'label': 'POSITIVE', 'score': 0.9220067262649536},
#  {'label': 'POSITIVE', 'score': 0.9998730421066284},
#  {'label': 'NEGATIVE', 'score': 0.9979220032691956},
#  {'label': 'POSITIVE', 'score': 0.9992958307266235},
#  {'label': 'NEGATIVE', 'score': 0.9994958639144897},
#  {'label': 'POSITIVE', 'score': 0.9997144341468811},
#  {'label': 'POSITIVE', 'score': 0.9997288584709167},
#  {'label': 'POSITIVE', 'score': 0.9998098015785217},
#  {'label': 'POSITIVE', 'score': 0.9991193413734436},
#  {'label': 'POSITIVE', 'score': 0.9997180104255676},
#  {'label': 'POSITIVE', 'score': 0.9998468160629272},
#  {'label': 'POSITIVE', 'score': 0.9979920387268066},
#  {'label': 'POSITIVE', 'score': 0.9963591694831848},
#  {'label': 'POSITIVE', 'score': 0.9998788833618164},
#  {'label': 'POSITIVE', 'score': 0.9998854398727417},
#  {'label': 'POSITIVE', 'score': 0.9994812607765198},
#  {'label': 'NEGATIVE', 'score': 0.9983110427856445},
#  {'label': 'POSITIVE', 'score': 0.9995367527008057},
#  {'label': 'POSITIVE', 'score': 0.9995040893554688},
#  {'label': 'POSITIVE', 'score': 0.9998317956924438},
#  {'label': 'POSITIVE', 'score': 0.9701303839683533},
#  {'label': 'POSITIVE', 'score': 0.9995013475418091},
#  {'label': 'POSITIVE', 'score': 0.9985520243644714},
#  {'label': 'POSITIVE', 'score': 0.9998648166656494},
#  {'label': 'NEGATIVE', 'score': 0.9944394826889038},
#  {'label': 'POSITIVE', 'score': 0.999152421951294},
#  {'label': 'POSITIVE', 'score': 0.9994401335716248},
#  {'label': 'POSITIVE', 'score': 0.9998268485069275},
#  {'label': 'NEGATIVE', 'score': 0.9295812249183655},
#  {'label': 'POSITIVE', 'score': 0.9998495578765869},
#  {'label': 'POSITIVE', 'score': 0.9994307160377502},
#  {'label': 'POSITIVE', 'score': 0.9961756467819214},
#  {'label': 'POSITIVE', 'score': 0.9991484880447388},
#  {'label': 'POSITIVE', 'score': 0.9882904291152954},
#  {'label': 'POSITIVE', 'score': 0.9998316764831543},
#  {'label': 'POSITIVE', 'score': 0.9989551305770874},
#  {'label': 'NEGATIVE', 'score': 0.9640312790870667},
#  {'label': 'POSITIVE', 'score': 0.9998321533203125},
#  {'label': 'NEGATIVE', 'score': 0.9968575239181519},
#  {'label': 'POSITIVE', 'score': 0.8789816498756409},
#  {'label': 'POSITIVE', 'score': 0.9994412064552307},
#  {'label': 'POSITIVE', 'score': 0.9995009899139404},
#  {'label': 'POSITIVE', 'score': 0.9994357228279114},
#  {'label': 'POSITIVE', 'score': 0.999870777130127},
#  {'label': 'POSITIVE', 'score': 0.993874728679657},
#  {'label': 'POSITIVE', 'score': 0.9996970891952515},
#  {'label': 'POSITIVE', 'score': 0.9577736854553223},
#  {'label': 'NEGATIVE', 'score': 0.9123199582099915},
#  {'label': 'POSITIVE', 'score': 0.9990334510803223},
#  {'label': 'POSITIVE', 'score': 0.9994878768920898},
#  {'label': 'POSITIVE', 'score': 0.9998825788497925},
#  {'label': 'POSITIVE', 'score': 0.9989225268363953},
#  {'label': 'POSITIVE', 'score': 0.9993576407432556},
#  {'label': 'POSITIVE', 'score': 0.9928991794586182},
#  {'label': 'POSITIVE', 'score': 0.9737508893013},
#  {'label': 'POSITIVE', 'score': 0.9996763467788696},
#  {'label': 'POSITIVE', 'score': 0.9995903372764587},
#  {'label': 'NEGATIVE', 'score': 0.9850693345069885},
#  {'label': 'POSITIVE', 'score': 0.9997950196266174},
#  {'label': 'POSITIVE', 'score': 0.9956309795379639},
#  {'label': 'POSITIVE', 'score': 0.9997358918190002},
#  {'label': 'POSITIVE', 'score': 0.9994521737098694},
#  {'label': 'POSITIVE', 'score': 0.9942746758460999},
#  {'label': 'POSITIVE', 'score': 0.999396800994873},
#  {'label': 'NEGATIVE', 'score': 0.9935543537139893},
#  {'label': 'NEGATIVE', 'score': 0.9838172197341919},
#  {'label': 'POSITIVE', 'score': 0.9951582551002502},
#  {'label': 'POSITIVE', 'score': 0.9993628859519958},
#  {'label': 'POSITIVE', 'score': 0.9959447979927063},
#  {'label': 'POSITIVE', 'score': 0.9989379048347473},
#  {'label': 'POSITIVE', 'score': 0.9854556918144226},
#  {'label': 'POSITIVE', 'score': 0.999862790107727},
#  {'label': 'POSITIVE', 'score': 0.9998652935028076},
#  {'label': 'NEGATIVE', 'score': 0.9961274266242981},
#  {'label': 'POSITIVE', 'score': 0.9997922778129578},
#  {'label': 'POSITIVE', 'score': 0.990951657295227},
#  {'label': 'POSITIVE', 'score': 0.9376334547996521},
#  {'label': 'POSITIVE', 'score': 0.9996284246444702},
#  {'label': 'POSITIVE', 'score': 0.9843875169754028},
#  {'label': 'POSITIVE', 'score': 0.8584072589874268},
#  {'label': 'POSITIVE', 'score': 0.9530424475669861},
#  {'label': 'POSITIVE', 'score': 0.9306883811950684},
#  {'label': 'NEGATIVE', 'score': 0.9780092239379883},
#  {'label': 'POSITIVE', 'score': 0.9902246594429016},
#  {'label': 'POSITIVE', 'score': 0.9997630715370178},
#  {'label': 'POSITIVE', 'score': 0.9953408241271973},
#  {'label': 'NEGATIVE', 'score': 0.9989590644836426},
#  {'label': 'POSITIVE', 'score': 0.998855710029602},
#  {'label': 'POSITIVE', 'score': 0.9995819926261902},
#  {'label': 'POSITIVE', 'score': 0.9990329742431641},
#  {'label': 'POSITIVE', 'score': 0.995400607585907},
#  {'label': 'POSITIVE', 'score': 0.9991801381111145},
#  {'label': 'POSITIVE', 'score': 0.9988635778427124},
#  {'label': 'NEGATIVE', 'score': 0.8635166883468628},
#  {'label': 'NEGATIVE', 'score': 0.9929872155189514},
#  {'label': 'POSITIVE', 'score': 0.9998015761375427},
#  {'label': 'POSITIVE', 'score': 0.9727458357810974},
#  {'label': 'POSITIVE', 'score': 0.9855378270149231},
#  {'label': 'NEGATIVE', 'score': 0.9960927367210388},
#  {'label': 'POSITIVE', 'score': 0.9997335076332092},
#  {'label': 'POSITIVE', 'score': 0.9987943172454834},
#  {'label': 'POSITIVE', 'score': 0.9996318817138672},
#  {'label': 'POSITIVE', 'score': 0.9997069239616394},
#  {'label': 'NEGATIVE', 'score': 0.9692932367324829},
#  {'label': 'POSITIVE', 'score': 0.9983355402946472},
#  {'label': 'POSITIVE', 'score': 0.999813973903656},
#  {'label': 'POSITIVE', 'score': 0.9997017979621887},
#  {'label': 'POSITIVE', 'score': 0.9990431666374207},
#  {'label': 'POSITIVE', 'score': 0.9810582399368286},
#  {'label': 'POSITIVE', 'score': 0.9997437596321106},
#  {'label': 'NEGATIVE', 'score': 0.9994394183158875},
#  {'label': 'POSITIVE', 'score': 0.9998584985733032},
#  {'label': 'POSITIVE', 'score': 0.9998615980148315},
#  {'label': 'NEGATIVE', 'score': 0.9995834231376648},
#  {'label': 'POSITIVE', 'score': 0.9998099207878113},
#  {'label': 'POSITIVE', 'score': 0.9997040629386902},
#  {'label': 'NEGATIVE', 'score': 0.7772470712661743},
#  {'label': 'POSITIVE', 'score': 0.9998569488525391},
#  {'label': 'POSITIVE', 'score': 0.9998575448989868},
#  {'label': 'POSITIVE', 'score': 0.7284140586853027},
#  {'label': 'POSITIVE', 'score': 0.9997605681419373},
#  {'label': 'NEGATIVE', 'score': 0.987891674041748},
#  {'label': 'POSITIVE', 'score': 0.975402295589447},
#  {'label': 'POSITIVE', 'score': 0.9997525811195374},
#  {'label': 'POSITIVE', 'score': 0.999756395816803},
#  {'label': 'POSITIVE', 'score': 0.9997510313987732},
#  {'label': 'POSITIVE', 'score': 0.9858049750328064},
#  {'label': 'POSITIVE', 'score': 0.9998794794082642},
#  {'label': 'POSITIVE', 'score': 0.7764118313789368},
#  {'label': 'NEGATIVE', 'score': 0.9388018846511841},
#  {'label': 'POSITIVE', 'score': 0.9643157720565796},
#  {'label': 'NEGATIVE', 'score': 0.9822632670402527},
#  {'label': 'POSITIVE', 'score': 0.9989423155784607},
#  {'label': 'POSITIVE', 'score': 0.9896376132965088},
#  {'label': 'POSITIVE', 'score': 0.9997239708900452},
#  {'label': 'NEGATIVE', 'score': 0.9279291033744812},
#  {'label': 'NEGATIVE', 'score': 0.8792505860328674},
#  {'label': 'POSITIVE', 'score': 0.995955228805542},
#  {'label': 'POSITIVE', 'score': 0.9947486519813538},
#  {'label': 'POSITIVE', 'score': 0.9995792508125305},
#  {'label': 'NEGATIVE', 'score': 0.9938309192657471},
#  {'label': 'POSITIVE', 'score': 0.9970851540565491},
#  {'label': 'POSITIVE', 'score': 0.6167905330657959},
#  {'label': 'POSITIVE', 'score': 0.9998905658721924},
#  {'label': 'POSITIVE', 'score': 0.9997574687004089},
#  {'label': 'NEGATIVE', 'score': 0.9929890632629395},
#  {'label': 'POSITIVE', 'score': 0.9993442893028259},
#  {'label': 'POSITIVE', 'score': 0.9998267292976379},
#  {'label': 'POSITIVE', 'score': 0.9997555613517761},
#  {'label': 'NEGATIVE', 'score': 0.8968662619590759},
#  {'label': 'POSITIVE', 'score': 0.9993864297866821},
#  {'label': 'POSITIVE', 'score': 0.9998461008071899},
#  {'label': 'POSITIVE', 'score': 0.9992783665657043},
#  {'label': 'POSITIVE', 'score': 0.9997088313102722},
#  {'label': 'NEGATIVE', 'score': 0.999778687953949},
#  {'label': 'POSITIVE', 'score': 0.9993027448654175},
#  {'label': 'POSITIVE', 'score': 0.9997928738594055},
#  {'label': 'POSITIVE', 'score': 0.9997033476829529},
#  {'label': 'POSITIVE', 'score': 0.9997833371162415},
#  {'label': 'POSITIVE', 'score': 0.9968222379684448},
#  {'label': 'POSITIVE', 'score': 0.9990031123161316},
#  {'label': 'NEGATIVE', 'score': 0.9802590608596802},
#  {'label': 'POSITIVE', 'score': 0.9985093474388123},
#  {'label': 'POSITIVE', 'score': 0.9682769179344177},
#  {'label': 'POSITIVE', 'score': 0.9998711347579956},
#  {'label': 'POSITIVE', 'score': 0.9945928454399109},
#  {'label': 'POSITIVE', 'score': 0.9997356534004211},
#  {'label': 'POSITIVE', 'score': 0.9998798370361328},
#  {'label': 'POSITIVE', 'score': 0.9996063113212585},
#  {'label': 'POSITIVE', 'score': 0.9993544220924377},
#  {'label': 'NEGATIVE', 'score': 0.9998030066490173},
#  {'label': 'NEGATIVE', 'score': 0.9997367262840271},
#  {'label': 'POSITIVE', 'score': 0.9997542500495911},
#  {'label': 'POSITIVE', 'score': 0.9998050332069397},
#  {'label': 'POSITIVE', 'score': 0.9993085861206055},
#  {'label': 'POSITIVE', 'score': 0.9998831748962402},
#  {'label': 'POSITIVE', 'score': 0.9993360638618469},
#  {'label': 'POSITIVE', 'score': 0.9997348189353943},
#  {'label': 'POSITIVE', 'score': 0.999626874923706},
#  {'label': 'POSITIVE', 'score': 0.9996863603591919},
#  {'label': 'POSITIVE', 'score': 0.9998784065246582},
#  {'label': 'POSITIVE', 'score': 0.9998666048049927},
#  {'label': 'POSITIVE', 'score': 0.9852991104125977},
#  {'label': 'POSITIVE', 'score': 0.8382791876792908},
#  {'label': 'NEGATIVE', 'score': 0.8333367109298706},
#  {'label': 'POSITIVE', 'score': 0.9998207688331604},
#  {'label': 'POSITIVE', 'score': 0.9994575381278992},
#  {'label': 'POSITIVE', 'score': 0.999840497970581},
#  {'label': 'POSITIVE', 'score': 0.9934397339820862},
#  {'label': 'POSITIVE', 'score': 0.9894468784332275},
#  {'label': 'POSITIVE', 'score': 0.9846483469009399},
#  {'label': 'NEGATIVE', 'score': 0.9965325593948364},
#  {'label': 'NEGATIVE', 'score': 0.9028549790382385},
#  {'label': 'POSITIVE', 'score': 0.9542849063873291},
#  {'label': 'NEGATIVE', 'score': 0.9016977548599243},
#  {'label': 'NEGATIVE', 'score': 0.9933884143829346},
#  {'label': 'NEGATIVE', 'score': 0.9907688498497009},
#  {'label': 'POSITIVE', 'score': 0.9987112283706665},
#  {'label': 'NEGATIVE', 'score': 0.9997891783714294},
#  {'label': 'NEGATIVE', 'score': 0.9989219903945923},
#  {'label': 'NEGATIVE', 'score': 0.9991177916526794},
#  {'label': 'POSITIVE', 'score': 0.9862496852874756},
#  {'label': 'NEGATIVE', 'score': 0.9893390536308289},
#  {'label': 'NEGATIVE', 'score': 0.9989965558052063},
#  {'label': 'POSITIVE', 'score': 0.9946840405464172},
#  {'label': 'NEGATIVE', 'score': 0.9983747005462646},
#  {'label': 'POSITIVE', 'score': 0.9519439339637756},
#  {'label': 'NEGATIVE', 'score': 0.9994388222694397},
#  {'label': 'NEGATIVE', 'score': 0.993033766746521},
#  {'label': 'NEGATIVE', 'score': 0.7963246703147888},
#  {'label': 'POSITIVE', 'score': 0.9969052672386169},
#  {'label': 'POSITIVE', 'score': 0.9411410689353943},
#  {'label': 'NEGATIVE', 'score': 0.9466842412948608},
#  {'label': 'POSITIVE', 'score': 0.9998840093612671},
#  {'label': 'NEGATIVE', 'score': 0.998170018196106},
#  {'label': 'NEGATIVE', 'score': 0.9110509157180786},
#  {'label': 'POSITIVE', 'score': 0.9998434782028198},
#  {'label': 'POSITIVE', 'score': 0.9994847774505615},
#  {'label': 'NEGATIVE', 'score': 0.9975382089614868},
#  {'label': 'POSITIVE', 'score': 0.9961785078048706},
#  {'label': 'POSITIVE', 'score': 0.9887446165084839},
#  {'label': 'POSITIVE', 'score': 0.9986133575439453},
#  {'label': 'POSITIVE', 'score': 0.9969052672386169},
#  {'label': 'POSITIVE', 'score': 0.9411410689353943},
#  {'label': 'NEGATIVE', 'score': 0.9466842412948608},
#  {'label': 'POSITIVE', 'score': 0.9998840093612671},
#  {'label': 'NEGATIVE', 'score': 0.998170018196106},
#  {'label': 'NEGATIVE', 'score': 0.9110509157180786},
#  {'label': 'POSITIVE', 'score': 0.9998434782028198},
#  {'label': 'POSITIVE', 'score': 0.9994847774505615},
#  {'label': 'NEGATIVE', 'score': 0.9975382089614868},
#  {'label': 'NEGATIVE', 'score': 0.8931778073310852},
#  {'label': 'POSITIVE', 'score': 0.9941199421882629},
#  {'label': 'NEGATIVE', 'score': 0.9921861886978149},
#  {'label': 'POSITIVE', 'score': 0.9104856252670288},
#  {'label': 'NEGATIVE', 'score': 0.9992623925209045},
#  {'label': 'POSITIVE', 'score': 0.9933997392654419},
#  {'label': 'NEGATIVE', 'score': 0.9863603115081787},
#  {'label': 'NEGATIVE', 'score': 0.9981368780136108},
#  {'label': 'NEGATIVE', 'score': 0.9699544906616211},
#  {'label': 'NEGATIVE', 'score': 0.7567639350891113},
#  {'label': 'POSITIVE', 'score': 0.9872651100158691},
#  {'label': 'NEGATIVE', 'score': 0.9997606873512268},
#  {'label': 'NEGATIVE', 'score': 0.9988491535186768},
#  {'label': 'NEGATIVE', 'score': 0.9982752799987793},
#  {'label': 'NEGATIVE', 'score': 0.9996861219406128},
#  {'label': 'NEGATIVE', 'score': 0.9997768998146057},
#  {'label': 'POSITIVE', 'score': 0.7195913791656494},
#  {'label': 'NEGATIVE', 'score': 0.9997870326042175},
#  {'label': 'NEGATIVE', 'score': 0.9929375052452087},
#  {'label': 'NEGATIVE', 'score': 0.9985255599021912},
#  {'label': 'NEGATIVE', 'score': 0.9966458678245544},
#  {'label': 'NEGATIVE', 'score': 0.9991744160652161},
#  {'label': 'NEGATIVE', 'score': 0.9904896020889282},
#  {'label': 'NEGATIVE', 'score': 0.9998168349266052},
#  {'label': 'NEGATIVE', 'score': 0.9993322491645813},
#  {'label': 'NEGATIVE', 'score': 0.997163712978363},
#  ...]

# %%
hf_review_sent = [0]*len(data['Product Review'])

for product in range(len(data['Product Review'])):
    if hf_review_dict[product]['label'] == 'POSITIVE':
        hf_review_sent[product] = 'POSITIVE'
    elif hf_review_dict[product]['label'] == 'NEUTRAL':
        hf_review_sent[product] = 'NEUTRAL'
    else:
        hf_review_sent[product] = 'NEGATIVE'

# %%
plot_confusion_matrix(y, hf_review_sent)

# %%
print(classification_report(y, hf_review_sent))
# Out:
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.23      0.92      0.37        74
#      NEUTRAL       0.00      0.00      0.00        81
#     POSITIVE       0.95      0.80      0.87       850
#
#     accuracy                           0.74      1005
#    macro avg       0.39      0.57      0.41      1005
# weighted avg       0.82      0.74      0.76      1005

# %% [markdown]
# ### **FLAN-T5**

# %%
# Defining the input and target variables
X = data['Product Review']
y = data["Sentiment"]

# %%
# initializing a T5 tokenizer using the pre-trained model
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-large")
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %%
# initializing a T5 model for conditional generation using the pre-trained model "google/flan-t5-large"
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-large", load_in_8bit=True, device_map="auto")
# Out:
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
# defining a function to generate, process, and return a response
def generate_response(prompt):
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to("cuda")    ### using the tokenizer to create tokens in tensor format from an input
    outputs = model.generate(input_ids, max_length=16, do_sample=True, temperature=0.001)    ### generating the model output in tensor format
    return tokenizer.decode(outputs[0])[6:-4]    ### using the tokenizer to decode the model output, and then return it

# %%
# checking a customer review and it's sentiment
print('Review:\t', X[4])
print('Actual Sentiment:\t', y[4])
# Out:
# Review:	 I have to say upfront - I don't like coroporate, hermetically closed stuff like anything by Apple or in this case, Amazon. I like having devices on which I can put anything I want and use it. But...I was a fairly happy user of a Nook Touch for several years, but couldn't use all its functionalities since I live in Serbia. Then I lost the Nook and since no other devices can actually be fully used in Serbia (buying books with them, using their online capabilities) except the Kindle, and since no one except Amazon ships to Serbia, and since I've actually been a happy Amazon customer since 2005 over friends' accounts and since 2007 through my own, and since the Kindle definitely has the best technology - why not buy itSo I did. What I read in many reviews about the screen/light of the Paperwhite and similar devices was no problem with mine. The light disperses just fine, except a few black blotches (maybe you can see it in the picture) at the bottom of the screen, which are actually shadows of the black plastic casing and thus can't really be avoided. As you can see in the picture without the light - there are no blotches with light out.The Paperwhite's screen is just marvelous at 300 ppi, the touchscreen works just fine, the store works here in Serbia, and in these two days I've been using it, I'm a happy guy.I had to get the hang on how to make sideloaded books behave at least almost like Amazon books, but that's fine. That's the one thing I'd like to see Amazon do in some future upgrades: make the Kindle treat sideloaded books just like the ones bought from them directly, with sharing funcion (quotes and Goodreads) enabled and so on.The size is perfect, it sits very well in the hand, the light doesn't hurt the eyes in the dark (like the light on a tab does)... the packaging was fine, no problems there and what remains to be seen now is the battery life.So far, I can only recommend it.
# Actual Sentiment:	 POSITIVE

# %%
# defining a prompt which tells the model what to do
sys_prompt = """
    Categorize the sentiment of the review as positive or negative or neutral.
    Return NEGATIVE for negative, NEUTRAL for neutral and POSITIVE for positive
"""

# predicting the sentiment using the model by incorporating the system prompt and the provided review text

pred_sent = generate_response(
    """
        {}
        Review text: '{}'
    """.format(sys_prompt, X[4])
)

print(pred_sent)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (515 > 512). Running this sequence through the model will result in indexing errors
# POSITIVE

# %% [markdown]
# - The model was able to correctly identify the sentiment here.

# %%
# defining a function to generate a sentiment prediction
def predict_sentiment(review_text):
    pred = generate_response(
        """
            {}
            Review text: '{}'
        """.format(sys_prompt, review_text)
    )

    return pred

# %%
# making predictions with the model
predicted_sentiment = [predict_sentiment(X[item]) for item in range(len(X))]
# must be careful with an LLM. It just gives you what it 'thinks' you want, which may not be what you actually want
# it's not uncommon for the returned value to not match the format you ask for!
# for example, several times predict_sentiment has returned '2 for positive' instead of just 2!

# %%
plot_confusion_matrix(y, predicted_sentiment)

# %%
print(classification_report(y, predicted_sentiment))
# Out:
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.47      0.97      0.64        74
#      NEUTRAL       0.00      0.00      0.00        81
#     POSITIVE       0.95      0.96      0.95       850
#
#     accuracy                           0.88      1005
#    macro avg       0.48      0.64      0.53      1005
# weighted avg       0.84      0.88      0.85      1005

# %% [markdown]
# # Conclusion

# %% [markdown]
# - We analyzed the distribution of sentiments of the customers.
#
# - We then built an ML model (Random Forest) with the Sentence transformer and pre-trained models (using pipeline and LLM prompt).
#
# - The Random Forest with encodings from sentence transformer model is the best model and was able to achieve a recall score of 90% and 87% on the train and test dataset respectively.

# %% [markdown]
# - By pinpointing areas of improvement or concerns raised by customers based on the predictions of the model, the organization can take swift and targeted actions to address issues, minimizing the risk of revenue loss and bolstering customer satisfaction.
#
# - The organization can leverage sentiment categorizations to tailor marketing strategies.
#     - Highlighting positive sentiments in promotional material can contribute to a positive brand image.
#     - They can use neutral and negative sentiments to make informed decisions around inventory.

# %% [markdown]
# <font size=6 color='blue'>Power Ahead</font>
# ___
